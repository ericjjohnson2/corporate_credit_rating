# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint
import pandas as pd
import sqlite3

# %%
connection = sqlite3.connect('../data/db.sqlite')

# Import DB into pandas dataframe
df = pd.read_sql_query("SELECT * FROM ratings", connection)

connection.close()

df.head()
# Out:
#                         Rating Agency                     Corporation Rating  \
# 0  Standard & Poor's Ratings Services       American States Water Co.     A-
# 1  Standard & Poor's Ratings Services  Automatic Data Processing Inc.    AAA
# 2  Standard & Poor's Ratings Services                      Avnet Inc.   BBB-
# 3  Standard & Poor's Ratings Services    California Water Service Co.    AA-
# 4  Standard & Poor's Ratings Services            Cardinal Health Inc.      A
#
#   Rating Date      CIK  Binary Rating  SIC Code Sector Ticker  Current Ratio  \
# 0  2010-07-30  1056903              1    4941.0  Utils    AWR         1.1507
# 1  2010-09-16     8670              1    7374.0  BusEq    ADP         1.1129
# 2  2010-11-23     8858              1    5065.0  Shops    AVT         1.9276
# 3  2010-06-29  1035201              1    4941.0  Utils    CWT         0.8358
# 4  2010-07-14   721371              1    5122.0  Shops    CAH         1.2931
#
#    ...  EBITDA Margin  Pre-Tax Profit Margin  Net Profit Margin  \
# 0  ...        28.9834                13.6093             8.3224
# 1  ...        23.9379                20.8699            13.5690
# 2  ...         3.6338                 3.0536             2.1418
# 3  ...        27.9377                15.1135             9.0246
# 4  ...         1.5847                 1.2304             0.6518
#
#    Asset Turnover  ROE - Return On Equity  Return On Tangible Equity  \
# 0          0.3173                  8.1724                     8.1978
# 1          0.3324                 22.0354                    47.2858
# 2          2.4620                 13.6376                    16.7991
# 3          0.2946                  9.6412                     9.7015
# 4          4.9276                 11.1256                    19.4184
#
#    ROA - Return On Assets  ROI - Return On Investment  \
# 0                  2.6385                      4.4530
# 1                  4.4944                     21.8765
# 2                  5.2731                      9.6494
# 3                  2.6583                      5.1018
# 4                  2.9364                      8.1844
#
#    Operating Cash Flow Per Share  Free Cash Flow Per Share
# 0                         1.9957                   -0.1333
# 1                         0.2501                    0.3132
# 2                        -7.6079                   -7.3231
# 3                         1.7438                   -0.8999
# 4                         1.9725                    2.4174
#
# [5 rows x 25 columns]

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
reduced_df = df.drop(columns=['Corporation', 'CIK', 'Ticker'])
reduced_df.head()
# Out:
#                         Rating Agency Rating Rating Date  Binary Rating  \
# 0  Standard & Poor's Ratings Services     A-  2010-07-30              1
# 1  Standard & Poor's Ratings Services    AAA  2010-09-16              1
# 2  Standard & Poor's Ratings Services   BBB-  2010-11-23              1
# 3  Standard & Poor's Ratings Services    AA-  2010-06-29              1
# 4  Standard & Poor's Ratings Services      A  2010-07-14              1
#
#    SIC Code Sector  Current Ratio  Long-term Debt / Capital  \
# 0    4941.0  Utils         1.1507                    0.4551
# 1    7374.0  BusEq         1.1129                    0.0072
# 2    5065.0  Shops         1.9276                    0.2924
# 3    4941.0  Utils         0.8358                    0.4708
# 4    5122.0  Shops         1.2931                    0.2644
#
#    Debt/Equity Ratio  Gross Margin  ...  EBITDA Margin  Pre-Tax Profit Margin  \
# 0             0.8847       77.6230  ...        28.9834                13.6093
# 1             0.0073       43.6619  ...        23.9379                20.8699
# 2             0.4255       11.9008  ...         3.6338                 3.0536
# 3             0.9491       64.5096  ...        27.9377                15.1135
# 4             0.4036        3.8385  ...         1.5847                 1.2304
#
#    Net Profit Margin  Asset Turnover  ROE - Return On Equity  \
# 0             8.3224          0.3173                  8.1724
# 1            13.5690          0.3324                 22.0354
# 2             2.1418          2.4620                 13.6376
# 3             9.0246          0.2946                  9.6412
# 4             0.6518          4.9276                 11.1256
#
#    Return On Tangible Equity  ROA - Return On Assets  \
# 0                     8.1978                  2.6385
# 1                    47.2858                  4.4944
# 2                    16.7991                  5.2731
# 3                     9.7015                  2.6583
# 4                    19.4184                  2.9364
#
#    ROI - Return On Investment  Operating Cash Flow Per Share  \
# 0                      4.4530                         1.9957
# 1                     21.8765                         0.2501
# 2                      9.6494                        -7.6079
# 3                      5.1018                         1.7438
# 4                      8.1844                         1.9725
#
#    Free Cash Flow Per Share
# 0                   -0.1333
# 1                    0.3132
# 2                   -7.3231
# 3                   -0.8999
# 4                    2.4174
#
# [5 rows x 22 columns]

# %%
# Determine the number of unique values in each column.
reduced_df.nunique()
# Out:
# Rating Agency                       7
# Rating                             23
# Rating Date                      1414
# Binary Rating                       2
# SIC Code                          240
# Sector                             12
# Current Ratio                    2521
# Long-term Debt / Capital         2241
# Debt/Equity Ratio                2484
# Gross Margin                     2601
# Operating Margin                 2648
# EBIT Margin                      2648
# EBITDA Margin                    2649
# Pre-Tax Profit Margin            2649
# Net Profit Margin                2642
# Asset Turnover                   2424
# ROE - Return On Equity           2651
# Return On Tangible Equity        2648
# ROA - Return On Assets           2632
# ROI - Return On Investment       2641
# Operating Cash Flow Per Share    2590
# Free Cash Flow Per Share         2585
# dtype: int64

# %%
# Used code from https://stackoverflow.com/questions/14247586/how-to-select-rows-with-one-or-more-nulls-from-a-pandas-dataframe-without-listin
# Look for nulls
def nans(df): return df[df.isnull().any(axis=1)]
nans(reduced_df)
# Out:
# Empty DataFrame
# Columns: [Rating Agency, Rating, Rating Date, Binary Rating, SIC Code, Sector, Current Ratio, Long-term Debt / Capital, Debt/Equity Ratio, Gross Margin, Operating Margin, EBIT Margin, EBITDA Margin, Pre-Tax Profit Margin, Net Profit Margin, Asset Turnover, ROE - Return On Equity, Return On Tangible Equity, ROA - Return On Assets, ROI - Return On Investment, Operating Cash Flow Per Share, Free Cash Flow Per Share]
# Index: []
#
# [0 rows x 22 columns]

# %%
# Checking for NA's
def nans2(df): return df[df.isna().any(axis=1)]
nans2(reduced_df)
# Out:
# Empty DataFrame
# Columns: [Rating Agency, Rating, Rating Date, Binary Rating, SIC Code, Sector, Current Ratio, Long-term Debt / Capital, Debt/Equity Ratio, Gross Margin, Operating Margin, EBIT Margin, EBITDA Margin, Pre-Tax Profit Margin, Net Profit Margin, Asset Turnover, ROE - Return On Equity, Return On Tangible Equity, ROA - Return On Assets, ROI - Return On Investment, Operating Cash Flow Per Share, Free Cash Flow Per Share]
# Index: []
#
# [0 rows x 22 columns]

# %%
# # Look at APPLICATION_TYPE value counts for binning
# application_counts = reduced_df['APPLICATION_TYPE'].value_counts()
# application_counts

# %%
# # Choose a cutoff value and create a list of application types to be replaced
# # use the variable name `application_types_to_replace`
# application_types_to_replace = list(application_counts[application_counts < 528].index)

# # Replace in dataframe
# for app in application_types_to_replace:
#     reduced_df['APPLICATION_TYPE'] = reduced_df['APPLICATION_TYPE'].replace(app,"Other")

# # Check to make sure binning was successful
# reduced_df['APPLICATION_TYPE'].value_counts()

# %%
# # Look at CLASSIFICATION value counts for binning
# classification_counts = reduced_df['CLASSIFICATION'].value_counts()
# classification_counts

# %%
# # You may find it helpful to look at CLASSIFICATION value counts >1
# class_counts_over1 = classification_counts.loc[classification_counts > 1]
# class_counts_over1

# %%
# # Choose a cutoff value and create a list of classifications to be replaced
# # use the variable name `classifications_to_replace`
# classifications_to_replace = list(classification_counts[classification_counts < 1000].index)

# # Replace in dataframe
# for cls in classifications_to_replace:
#     reduced_df['CLASSIFICATION'] = reduced_df['CLASSIFICATION'].replace(cls,"Other")

# # Check to make sure binning was successful
# reduced_df['CLASSIFICATION'].value_counts()

# %%
# Convert categorical data to numeric with `pd.get_dummies`
reduced_numeric = pd.get_dummies(reduced_df)

# %%
# Split our preprocessed data into our features and target arrays
X = reduced_numeric.drop(['Binary Rating'], axis=1)
y = reduced_numeric['Binary Rating']

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 4
hidden_nodes_layer2 = 3
hidden_nodes_layer3 = 2

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1,
             input_dim=number_input_features, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(
    units=hidden_nodes_layer2, activation="relu"))

# Third hidden layer
nn.add(tf.keras.layers.Dense(
    units=hidden_nodes_layer3, activation="sigmoid"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 4)                 5896
#
#  dense_1 (Dense)             (None, 3)                 15
#
#  dense_2 (Dense)             (None, 2)                 8
#
#  dense_3 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 5,922
# Trainable params: 5,922
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the model
# Used code from https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/ModelCheckpoint
# and from https://stackoverflow.com/questions/44886509/keras-save-checkpoints

EPOCHS = 20
checkpoint_filepath = '../models/model1/checkpoints/weights.epoch_{epoch:02d}.hdf5'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_freq=5,
    verbose=True)

# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
fit_model = nn.fit(X_train_scaled, y_train, epochs=EPOCHS, callbacks=[model_checkpoint_callback])
# Out:
# Epoch 1/20
# 2024-03-14 20:18:36.927526: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
#   1/183 [..............................] - ETA: 41s - loss: 0.6645 - accuracy: 0.6250
# Epoch 1: saving model to ../models/model1/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model1/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model1/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model1/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model1/checkpoints/weights.epoch_01.hdf5
#  25/183 [===>..........................] - ETA: 0s - loss: 0.6617 - accuracy: 0.6538
# Epoch 1: saving model to ../models/model1/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model1/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model1/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model1/checkpoints/weights.epoch_01.hdf5
#  45/183 [======>.......................] - ETA: 0s - loss: 0.6616 - accuracy: 0.6444
# Epoch 1: saving model to ../models/model1/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model1/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model1/checkpoints/weights.epoch_01.hdf5
#  60/183 [========>.....................] - ETA: 0s - loss: 0.6592 - accuracy: 0.6438
# Epoch 1: saving model to ../models/model1/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model1/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model1/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model1/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model1/checkpoints/weights.epoch_01.hdf5
#  85/183 [============>.................] - ETA: 0s - loss: 0.6584 - accuracy: 0.6371
# Epoch 1: saving model to ../models/model1/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model1/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model1/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model1/checkpoints/weights.epoch_01.hdf5
# 108/183 [================>.............] - ETA: 0s - loss: 0.6515 - accuracy: 0.6499
# Epoch 1: saving model to ../models/model1/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model1/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model1/checkpoints/weights.epoch_01.hdf5
# 123/183 [===================>..........] - ETA: 0s - loss: 0.6498 - accuracy: 0.6502
# Epoch 1: saving model to ../models/model1/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model1/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model1/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model1/checkpoints/weights.epoch_01.hdf5
# 141/183 [======================>.......] - ETA: 0s - loss: 0.6459 - accuracy: 0.6534
# Epoch 1: saving model to ../models/model1/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model1/checkpoints/weights.epoch_01.hdf5
# 150/183 [=======================>......] - ETA: 0s - loss: 0.6451 - accuracy: 0.6521
# Epoch 1: saving model to ../models/model1/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model1/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model1/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model1/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model1/checkpoints/weights.epoch_01.hdf5
# 175/183 [===========================>..] - ETA: 0s - loss: 0.6425 - accuracy: 0.6479
# Epoch 1: saving model to ../models/model1/checkpoints/weights.epoch_01.hdf5
# 183/183 [==============================] - 1s 3ms/step - loss: 0.6408 - accuracy: 0.6487
# Epoch 2/20
#   1/183 [..............................] - ETA: 0s - loss: 0.5866 - accuracy: 0.6562
# Epoch 2: saving model to ../models/model1/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model1/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model1/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model1/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model1/checkpoints/weights.epoch_02.hdf5
#  25/183 [===>..........................] - ETA: 0s - loss: 0.5805 - accuracy: 0.6675
# Epoch 2: saving model to ../models/model1/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model1/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model1/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model1/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model1/checkpoints/weights.epoch_02.hdf5
#  48/183 [======>.......................] - ETA: 0s - loss: 0.5819 - accuracy: 0.6504
# Epoch 2: saving model to ../models/model1/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model1/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model1/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model1/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model1/checkpoints/weights.epoch_02.hdf5
#  72/183 [==========>...................] - ETA: 0s - loss: 0.5753 - accuracy: 0.6528
# Epoch 2: saving model to ../models/model1/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model1/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model1/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model1/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model1/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model1/checkpoints/weights.epoch_02.hdf5
# 102/183 [===============>..............] - ETA: 0s - loss: 0.5669 - accuracy: 0.6532
# Epoch 2: saving model to ../models/model1/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model1/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model1/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model1/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model1/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model1/checkpoints/weights.epoch_02.hdf5
# 132/183 [====================>.........] - ETA: 0s - loss: 0.5625 - accuracy: 0.6449
# Epoch 2: saving model to ../models/model1/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model1/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model1/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model1/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model1/checkpoints/weights.epoch_02.hdf5
# 161/183 [=========================>....] - ETA: 0s - loss: 0.5535 - accuracy: 0.6473
# Epoch 2: saving model to ../models/model1/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model1/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model1/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model1/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model1/checkpoints/weights.epoch_02.hdf5
# 183/183 [==============================] - 0s 2ms/step - loss: 0.5469 - accuracy: 0.6487
# Epoch 3/20
#   1/183 [..............................] - ETA: 0s - loss: 0.4424 - accuracy: 0.7812
# Epoch 3: saving model to ../models/model1/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model1/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model1/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model1/checkpoints/weights.epoch_03.hdf5
#  19/183 [==>...........................] - ETA: 0s - loss: 0.4816 - accuracy: 0.6480
# Epoch 3: saving model to ../models/model1/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model1/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model1/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model1/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model1/checkpoints/weights.epoch_03.hdf5
#  44/183 [======>.......................] - ETA: 0s - loss: 0.4726 - accuracy: 0.6513
# Epoch 3: saving model to ../models/model1/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model1/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model1/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model1/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model1/checkpoints/weights.epoch_03.hdf5
#  72/183 [==========>...................] - ETA: 0s - loss: 0.4631 - accuracy: 0.6576
# Epoch 3: saving model to ../models/model1/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model1/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model1/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model1/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model1/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model1/checkpoints/weights.epoch_03.hdf5
#  99/183 [===============>..............] - ETA: 0s - loss: 0.4582 - accuracy: 0.6531
# Epoch 3: saving model to ../models/model1/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model1/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model1/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model1/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model1/checkpoints/weights.epoch_03.hdf5
# 124/183 [===================>..........] - ETA: 0s - loss: 0.4527 - accuracy: 0.6515
# Epoch 3: saving model to ../models/model1/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model1/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model1/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model1/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model1/checkpoints/weights.epoch_03.hdf5
# 150/183 [=======================>......] - ETA: 0s - loss: 0.4472 - accuracy: 0.6508
# Epoch 3: saving model to ../models/model1/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model1/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model1/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model1/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model1/checkpoints/weights.epoch_03.hdf5
# 177/183 [============================>.] - ETA: 0s - loss: 0.4427 - accuracy: 0.6487
# Epoch 3: saving model to ../models/model1/checkpoints/weights.epoch_03.hdf5
# 183/183 [==============================] - 0s 2ms/step - loss: 0.4418 - accuracy: 0.6487
# Epoch 4/20
#
# Epoch 4: saving model to ../models/model1/checkpoints/weights.epoch_04.hdf5
#   1/183 [..............................] - ETA: 1s - loss: 0.4854 - accuracy: 0.4688
# Epoch 4: saving model to ../models/model1/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model1/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model1/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model1/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model1/checkpoints/weights.epoch_04.hdf5
#  30/183 [===>..........................] - ETA: 0s - loss: 0.3887 - accuracy: 0.6490
# Epoch 4: saving model to ../models/model1/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model1/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model1/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model1/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model1/checkpoints/weights.epoch_04.hdf5
#  55/183 [========>.....................] - ETA: 0s - loss: 0.3888 - accuracy: 0.6398
# Epoch 4: saving model to ../models/model1/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model1/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model1/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model1/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model1/checkpoints/weights.epoch_04.hdf5
#  76/183 [===========>..................] - ETA: 0s - loss: 0.3840 - accuracy: 0.6443
# Epoch 4: saving model to ../models/model1/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model1/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model1/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model1/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model1/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model1/checkpoints/weights.epoch_04.hdf5
#
- accuracy: 1.0000
# Epoch 11: saving model to ../models/model1/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model1/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model1/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model1/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model1/checkpoints/weights.epoch_11.hdf5
# 150/183 [=======================>......] - ETA: 0s - loss: 0.1457 - accuracy: 1.0000
# Epoch 11: saving model to ../models/model1/checkpoints/weights.epoch_11.hdf5
# 157/183 [========================>.....] - ETA: 0s - loss: 0.1455 - accuracy: 1.0000
# Epoch 11: saving model to ../models/model1/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model1/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model1/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model1/checkpoints/weights.epoch_11.hdf5
# 176/183 [===========================>..] - ETA: 0s - loss: 0.1440 - accuracy: 1.0000
# Epoch 11: saving model to ../models/model1/checkpoints/weights.epoch_11.hdf5
# 183/183 [==============================] - 0s 2ms/step - loss: 0.1439 - accuracy: 1.0000
# Epoch 12/20
#   1/183 [..............................] - ETA: 0s - loss: 0.1338 - accuracy: 1.0000
# Epoch 12: saving model to ../models/model1/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model1/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model1/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model1/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model1/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model1/checkpoints/weights.epoch_12.hdf5
#  28/183 [===>..........................] - ETA: 0s - loss: 0.1300 - accuracy: 1.0000
# Epoch 12: saving model to ../models/model1/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model1/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model1/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model1/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model1/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model1/checkpoints/weights.epoch_12.hdf5
#  59/183 [========>.....................] - ETA: 0s - loss: 0.1323 - accuracy: 0.9995
# Epoch 12: saving model to ../models/model1/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model1/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model1/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model1/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model1/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model1/checkpoints/weights.epoch_12.hdf5
#  87/183 [=============>................] - ETA: 0s - loss: 0.1325 - accuracy: 0.9996
# Epoch 12: saving model to ../models/model1/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model1/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model1/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model1/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model1/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model1/checkpoints/weights.epoch_12.hdf5
# 118/183 [==================>...........] - ETA: 0s - loss: 0.1317 - accuracy: 0.9997
# Epoch 12: saving model to ../models/model1/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model1/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model1/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model1/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model1/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model1/checkpoints/weights.epoch_12.hdf5
# 147/183 [=======================>......] - ETA: 0s - loss: 0.1313 - accuracy: 0.9998
# Epoch 12: saving model to ../models/model1/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model1/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model1/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model1/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model1/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model1/checkpoints/weights.epoch_12.hdf5
# 177/183 [============================>.] - ETA: 0s - loss: 0.1295 - accuracy: 0.9998
# Epoch 12: saving model to ../models/model1/checkpoints/weights.epoch_12.hdf5
# 183/183 [==============================] - 0s 2ms/step - loss: 0.1293 - accuracy: 0.9998
# Epoch 13/20
#   1/183 [..............................] - ETA: 0s - loss: 0.1269 - accuracy: 1.0000
# Epoch 13: saving model to ../models/model1/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model1/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model1/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model1/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model1/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model1/checkpoints/weights.epoch_13.hdf5
#  29/183 [===>..........................] - ETA: 0s - loss: 0.1261 - accuracy: 1.0000
# Epoch 13: saving model to ../models/model1/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model1/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model1/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model1/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model1/checkpoints/weights.epoch_13.hdf5
#  56/183 [========>.....................] - ETA: 0s - loss: 0.1210 - accuracy: 1.0000
# Epoch 13: saving model to ../models/model1/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model1/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model1/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model1/checkpoints/weights.epoch_13.hdf5
#  74/183 [===========>..................] - ETA: 0s - loss: 0.1197 - accuracy: 1.0000
# Epoch 13: saving model to ../models/model1/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model1/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model1/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model1/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model1/checkpoints/weights.epoch_13.hdf5
#  99/183 [===============>..............] - ETA: 0s - loss: 0.1193 - accuracy: 1.0000
# Epoch 13: saving model to ../models/model1/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model1/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model1/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model1/checkpoints/weights.epoch_13.hdf5
# 123/183 [===================>..........] - ETA: 0s - loss: 0.1188 - accuracy: 1.0000
# Epoch 13: saving model to ../models/model1/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model1/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model1/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model1/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model1/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model1/checkpoints/weights.epoch_13.hdf5
# 149/183 [=======================>......] - ETA: 0s - loss: 0.1183 - accuracy: 1.0000
# Epoch 13: saving model to ../models/model1/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model1/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model1/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model1/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model1/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model1/checkpoints/weights.epoch_13.hdf5
# 183/183 [==============================] - 0s 2ms/step - loss: 0.1165 - accuracy: 1.0000
# Epoch 14/20
#
# Epoch 14: saving model to ../models/model1/checkpoints/weights.epoch_14.hdf5
#   1/183 [..............................] - ETA: 0s - loss: 0.1321 - accuracy: 1.0000
# Epoch 14: saving model to ../models/model1/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model1/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model1/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model1/checkpoints/weights.epoch_14.hdf5
#  21/183 [==>...........................] - ETA: 0s - loss: 0.1152 - accuracy: 1.0000
# Epoch 14: saving model to ../models/model1/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model1/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model1/checkpoints/weights.epoch_14.hdf5
#  37/183 [=====>........................] - ETA: 0s - loss: 0.1137 - accuracy: 1.0000
# Epoch 14: saving model to ../models/model1/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model1/checkpoints/weights.epoch_14.hdf5
#  49/183 [=======>......................] - ETA: 0s - loss: 0.1130 - accuracy: 1.0000
# Epoch 14: saving model to ../models/model1/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model1/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model1/checkpoints/weights.epoch_14.hdf5
#
# ...
#
# Epoch 16: saving model to ../models/model1/checkpoints/weights.epoch_16.hdf5
#
# Epoch 16: saving model to ../models/model1/checkpoints/weights.epoch_16.hdf5
#
# Epoch 16: saving model to ../models/model1/checkpoints/weights.epoch_16.hdf5
#  95/183 [==============>...............] - ETA: 0s - loss: 0.0876 - accuracy: 1.0000
# Epoch 16: saving model to ../models/model1/checkpoints/weights.epoch_16.hdf5
#
# Epoch 16: saving model to ../models/model1/checkpoints/weights.epoch_16.hdf5
#
# Epoch 16: saving model to ../models/model1/checkpoints/weights.epoch_16.hdf5
# 111/183 [=================>............] - ETA: 0s - loss: 0.0875 - accuracy: 1.0000
# Epoch 16: saving model to ../models/model1/checkpoints/weights.epoch_16.hdf5
#
# Epoch 16: saving model to ../models/model1/checkpoints/weights.epoch_16.hdf5
#
# Epoch 16: saving model to ../models/model1/checkpoints/weights.epoch_16.hdf5
#
# Epoch 16: saving model to ../models/model1/checkpoints/weights.epoch_16.hdf5
#
# Epoch 16: saving model to ../models/model1/checkpoints/weights.epoch_16.hdf5
#
# Epoch 16: saving model to ../models/model1/checkpoints/weights.epoch_16.hdf5
# 140/183 [=====================>........] - ETA: 0s - loss: 0.0871 - accuracy: 1.0000
# Epoch 16: saving model to ../models/model1/checkpoints/weights.epoch_16.hdf5
#
# Epoch 16: saving model to ../models/model1/checkpoints/weights.epoch_16.hdf5
#
# Epoch 16: saving model to ../models/model1/checkpoints/weights.epoch_16.hdf5
#
# Epoch 16: saving model to ../models/model1/checkpoints/weights.epoch_16.hdf5
#
# Epoch 16: saving model to ../models/model1/checkpoints/weights.epoch_16.hdf5
#
# Epoch 16: saving model to ../models/model1/checkpoints/weights.epoch_16.hdf5
#
# Epoch 16: saving model to ../models/model1/checkpoints/weights.epoch_16.hdf5
# 175/183 [===========================>..] - ETA: 0s - loss: 0.0869 - accuracy: 1.0000
# Epoch 16: saving model to ../models/model1/checkpoints/weights.epoch_16.hdf5
# 183/183 [==============================] - 0s 2ms/step - loss: 0.0864 - accuracy: 1.0000
# Epoch 17/20
#   1/183 [..............................] - ETA: 0s - loss: 0.0641 - accuracy: 1.0000
# Epoch 17: saving model to ../models/model1/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model1/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model1/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model1/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model1/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model1/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model1/checkpoints/weights.epoch_17.hdf5
#  32/183 [====>.........................] - ETA: 0s - loss: 0.0827 - accuracy: 1.0000
# Epoch 17: saving model to ../models/model1/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model1/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model1/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model1/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model1/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model1/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model1/checkpoints/weights.epoch_17.hdf5
#  67/183 [=========>....................] - ETA: 0s - loss: 0.0808 - accuracy: 1.0000
# Epoch 17: saving model to ../models/model1/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model1/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model1/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model1/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model1/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model1/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model1/checkpoints/weights.epoch_17.hdf5
# 102/183 [===============>..............] - ETA: 0s - loss: 0.0796 - accuracy: 1.0000
# Epoch 17: saving model to ../models/model1/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model1/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model1/checkpoints/weights.epoch_17.hdf5
# 117/183 [==================>...........] - ETA: 0s - loss: 0.0800 - accuracy: 1.0000
# Epoch 17: saving model to ../models/model1/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model1/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model1/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model1/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model1/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model1/checkpoints/weights.epoch_17.hdf5
# 147/183 [=======================>......] - ETA: 0s - loss: 0.0796 - accuracy: 1.0000
# Epoch 17: saving model to ../models/model1/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model1/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model1/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model1/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model1/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model1/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model1/checkpoints/weights.epoch_17.hdf5
# 183/183 [==============================] - 0s 2ms/step - loss: 0.0785 - accuracy: 1.0000
# Epoch 18/20
#   1/183 [..............................] - ETA: 0s - loss: 0.0622 - accuracy: 1.0000
# Epoch 18: saving model to ../models/model1/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model1/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model1/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model1/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model1/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model1/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model1/checkpoints/weights.epoch_18.hdf5
#  34/183 [====>.........................] - ETA: 0s - loss: 0.0720 - accuracy: 1.0000
# Epoch 18: saving model to ../models/model1/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model1/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model1/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model1/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model1/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model1/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model1/checkpoints/weights.epoch_18.hdf5
#  70/183 [==========>...................] - ETA: 0s - loss: 0.0735 - accuracy: 1.0000
# Epoch 18: saving model to ../models/model1/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model1/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model1/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model1/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model1/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model1/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model1/checkpoints/weights.epoch_18.hdf5
# 104/183 [================>.............] - ETA: 0s - loss: 0.0731 - accuracy: 1.0000
# Epoch 18: saving model to ../models/model1/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model1/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model1/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model1/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model1/checkpoints/weights.epoch_18.hdf5
# 132/183 [====================>.........] - ETA: 0s - loss: 0.0725 - accuracy: 1.0000
# Epoch 18: saving model to ../models/model1/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model1/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model1/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model1/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model1/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model1/checkpoints/weights.epoch_18.hdf5
# 159/183 [=========================>....] - ETA: 0s - loss: 0.0722 - accuracy: 1.0000
# Epoch 18: saving model to ../models/model1/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model1/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model1/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model1/checkpoints/weights.epoch_18.hdf5
# 183/183 [==============================] - 0s 2ms/step - loss: 0.0716 - accuracy: 1.0000
# Epoch 19/20
#
# Epoch 19: saving model to ../models/model1/checkpoints/weights.epoch_19.hdf5
#   1/183 [..............................] - ETA: 1s - loss: 0.0778 - accuracy: 1.0000
# Epoch 19: saving model to ../models/model1/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model1/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model1/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model1/checkpoints/weights.epoch_19.hdf5
#  21/183 [==>...........................] - ETA: 0s - loss: 0.0687 - accuracy: 1.0000
# Epoch 19: saving model to ../models/model1/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model1/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model1/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model1/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model1/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model1/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model1/checkpoints/weights.epoch_19.hdf5
#  56/183 [========>.....................] - ETA: 0s - loss: 0.0679 - accuracy: 1.0000
# Epoch 19: saving model to ../models/model1/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model1/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model1/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model1/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model1/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model1/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model1/checkpoints/weights.epoch_19.hdf5
#  91/183 [=============>................] - ETA: 0s - loss: 0.0671 - accuracy: 1.0000
# Epoch 19: saving model to ../models/model1/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model1/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model1/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model1/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model1/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model1/checkpoints/weights.epoch_19.hdf5
# 121/183 [==================>...........] - ETA: 0s - loss: 0.0665 - accuracy: 1.0000
# Epoch 19: saving model to ../models/model1/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model1/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model1/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model1/checkpoints/weights.epoch_19.hdf5
# 143/183 [======================>.......] - ETA: 0s - loss: 0.0658 - accuracy: 1.0000
# Epoch 19: saving model to ../models/model1/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model1/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model1/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model1/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model1/checkpoints/weights.epoch_19.hdf5
# 166/183 [==========================>...] - ETA: 0s - loss: 0.0652 - accuracy: 1.0000
# Epoch 19: saving model to ../models/model1/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model1/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model1/checkpoints/weights.epoch_19.hdf5
# 183/183 [==============================] - 0s 2ms/step - loss: 0.0652 - accuracy: 1.0000
# Epoch 20/20
#   1/183 [..............................] - ETA: 1s - loss: 0.0679 - accuracy: 1.0000
# Epoch 20: saving model to ../models/model1/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model1/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model1/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model1/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model1/checkpoints/weights.epoch_20.hdf5
#  23/183 [==>...........................] - ETA: 0s - loss: 0.0655 - accuracy: 1.0000
# Epoch 20: saving model to ../models/model1/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model1/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model1/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model1/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model1/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model1/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model1/checkpoints/weights.epoch_20.hdf5
#  58/183 [========>.....................] - ETA: 0s - loss: 0.0621 - accuracy: 1.0000
# Epoch 20: saving model to ../models/model1/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model1/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model1/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model1/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model1/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model1/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model1/checkpoints/weights.epoch_20.hdf5
#  94/183 [==============>...............] - ETA: 0s - loss: 0.0608 - accuracy: 1.0000
# Epoch 20: saving model to ../models/model1/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model1/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model1/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model1/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model1/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model1/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model1/checkpoints/weights.epoch_20.hdf5
# 128/183 [===================>..........] - ETA: 0s - loss: 0.0598 - accuracy: 1.0000
# Epoch 20: saving model to ../models/model1/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model1/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model1/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model1/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model1/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model1/checkpoints/weights.epoch_20.hdf5
# 160/183 [=========================>....] - ETA: 0s - loss: 0.0598 - accuracy: 1.0000
# Epoch 20: saving model to ../models/model1/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model1/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model1/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model1/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model1/checkpoints/weights.epoch_20.hdf5
# 183/183 [==============================] - 0s 2ms/step - loss: 0.0596 - accuracy: 1.0000

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 61/61 - 0s - loss: 0.1438 - accuracy: 0.9585 - 92ms/epoch - 2ms/step
# Loss: 0.14382968842983246, Accuracy: 0.9585040807723999

# %%
# Export our model to HDF5 file
nn.save('../models/model1/creditratings.h5')
