# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint
import pandas as pd
import sqlite3

# %%
connection = sqlite3.connect('../data/db.sqlite')

# Import DB into pandas dataframe
df = pd.read_sql_query("SELECT * FROM ratings", connection)

connection.close()

df.head()
# Out:
#                         Rating Agency                     Corporation Rating  \
# 0  Standard & Poor's Ratings Services       American States Water Co.     A-
# 1  Standard & Poor's Ratings Services  Automatic Data Processing Inc.    AAA
# 2  Standard & Poor's Ratings Services                      Avnet Inc.   BBB-
# 3  Standard & Poor's Ratings Services    California Water Service Co.    AA-
# 4  Standard & Poor's Ratings Services            Cardinal Health Inc.      A
#
#   Rating Date      CIK  Binary Rating  SIC Code Sector Ticker  Current Ratio  \
# 0  2010-07-30  1056903              1    4941.0  Utils    AWR         1.1507
# 1  2010-09-16     8670              1    7374.0  BusEq    ADP         1.1129
# 2  2010-11-23     8858              1    5065.0  Shops    AVT         1.9276
# 3  2010-06-29  1035201              1    4941.0  Utils    CWT         0.8358
# 4  2010-07-14   721371              1    5122.0  Shops    CAH         1.2931
#
#    ...  EBITDA Margin  Pre-Tax Profit Margin  Net Profit Margin  \
# 0  ...        28.9834                13.6093             8.3224
# 1  ...        23.9379                20.8699            13.5690
# 2  ...         3.6338                 3.0536             2.1418
# 3  ...        27.9377                15.1135             9.0246
# 4  ...         1.5847                 1.2304             0.6518
#
#    Asset Turnover  ROE - Return On Equity  Return On Tangible Equity  \
# 0          0.3173                  8.1724                     8.1978
# 1          0.3324                 22.0354                    47.2858
# 2          2.4620                 13.6376                    16.7991
# 3          0.2946                  9.6412                     9.7015
# 4          4.9276                 11.1256                    19.4184
#
#    ROA - Return On Assets  ROI - Return On Investment  \
# 0                  2.6385                      4.4530
# 1                  4.4944                     21.8765
# 2                  5.2731                      9.6494
# 3                  2.6583                      5.1018
# 4                  2.9364                      8.1844
#
#    Operating Cash Flow Per Share  Free Cash Flow Per Share
# 0                         1.9957                   -0.1333
# 1                         0.2501                    0.3132
# 2                        -7.6079                   -7.3231
# 3                         1.7438                   -0.8999
# 4                         1.9725                    2.4174
#
# [5 rows x 25 columns]

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
reduced_df = df.drop(columns=['Corporation', 'CIK', 'Ticker', 'Rating Agency', 'Rating Date', 'SIC Code',
       'Sector', 'Current Ratio', 'Long-term Debt / Capital',
        'Gross Margin', 'Operating Margin', 'EBIT Margin',
       'EBITDA Margin', 'Pre-Tax Profit Margin', 
       'Asset Turnover', 'Return On Tangible Equity',
       'ROA - Return On Assets', 
       'Operating Cash Flow Per Share', 'Free Cash Flow Per Share'])
reduced_df.head()
# Out:
#   Rating  Binary Rating  Debt/Equity Ratio  Net Profit Margin  \
# 0     A-              1             0.8847             8.3224
# 1    AAA              1             0.0073            13.5690
# 2   BBB-              1             0.4255             2.1418
# 3    AA-              1             0.9491             9.0246
# 4      A              1             0.4036             0.6518
#
#    ROE - Return On Equity  ROI - Return On Investment
# 0                  8.1724                      4.4530
# 1                 22.0354                     21.8765
# 2                 13.6376                      9.6494
# 3                  9.6412                      5.1018
# 4                 11.1256                      8.1844

# %%
reduced_df['ROE - Return On Equity'].describe()
# Out:
# count     7805.000000
# mean        15.950507
# std        230.592526
# min     -11258.210000
# 25%          6.022800
# 50%         12.500000
# 75%         20.515700
# max       7038.461000
# Name: ROE - Return On Equity, dtype: float64

# %%
reduced_df['Rating'].value_counts()
# Out:
# Rating
# BBB     910
# BBB+    846
# A       836
# A-      722
# BBB-    705
# BB+     545
# A+      478
# BB      453
# BB-     427
# B+      422
# B       310
# B-      288
# AA-     254
# AA      185
# CCC+    151
# AAA      90
# AA+      73
# CCC      65
# CC       18
# C        11
# CCC-     10
# D         5
# CC+       1
# Name: count, dtype: int64

# %%
# Determine the number of unique values in each column.
reduced_df.nunique()
# Out:
# Rating                          23
# Binary Rating                    2
# Debt/Equity Ratio             2484
# Net Profit Margin             2642
# ROE - Return On Equity        2651
# ROI - Return On Investment    2641
# dtype: int64

# %%
reduced_df.columns
# Out:
# Index(['Rating', 'Binary Rating', 'Debt/Equity Ratio', 'Net Profit Margin',
#        'ROE - Return On Equity', 'ROI - Return On Investment'],
#       dtype='object')

# %%
# Used code from https://stackoverflow.com/questions/14247586/how-to-select-rows-with-one-or-more-nulls-from-a-pandas-dataframe-without-listin
# Look for nulls
def nans(df): return df[df.isnull().any(axis=1)]
nans(reduced_df)
# Out:
# Empty DataFrame
# Columns: [Rating, Binary Rating, Debt/Equity Ratio, Net Profit Margin, ROE - Return On Equity, ROI - Return On Investment]
# Index: []

# %%
# Checking for NA's
def nans2(df): return df[df.isna().any(axis=1)]
nans2(reduced_df)
# Out:
# Empty DataFrame
# Columns: [Rating, Binary Rating, Debt/Equity Ratio, Net Profit Margin, ROE - Return On Equity, ROI - Return On Investment]
# Index: []

# %%
# # Look at APPLICATION_TYPE value counts for binning
# application_counts = reduced_df['APPLICATION_TYPE'].value_counts()
# application_counts

# %%
# # Choose a cutoff value and create a list of application types to be replaced
# # use the variable name `application_types_to_replace`
# application_types_to_replace = list(application_counts[application_counts < 528].index)

# # Replace in dataframe
# for app in application_types_to_replace:
#     reduced_df['APPLICATION_TYPE'] = reduced_df['APPLICATION_TYPE'].replace(app,"Other")

# # Check to make sure binning was successful
# reduced_df['APPLICATION_TYPE'].value_counts()

# %%
# # Look at CLASSIFICATION value counts for binning
# classification_counts = reduced_df['CLASSIFICATION'].value_counts()
# classification_counts

# %%
# # You may find it helpful to look at CLASSIFICATION value counts >1
# class_counts_over1 = classification_counts.loc[classification_counts > 1]
# class_counts_over1

# %%
# # Choose a cutoff value and create a list of classifications to be replaced
# # use the variable name `classifications_to_replace`
# classifications_to_replace = list(classification_counts[classification_counts < 1000].index)

# # Replace in dataframe
# for cls in classifications_to_replace:
#     reduced_df['CLASSIFICATION'] = reduced_df['CLASSIFICATION'].replace(cls,"Other")

# # Check to make sure binning was successful
# reduced_df['CLASSIFICATION'].value_counts()

# %%
# Convert categorical data to numeric with `pd.get_dummies`
reduced_numeric = pd.get_dummies(reduced_df)

# %%
reduced_numeric.head()
# Out:
#    Binary Rating  Debt/Equity Ratio  Net Profit Margin  \
# 0              1             0.8847             8.3224
# 1              1             0.0073            13.5690
# 2              1             0.4255             2.1418
# 3              1             0.9491             9.0246
# 4              1             0.4036             0.6518
#
#    ROE - Return On Equity  ROI - Return On Investment  Rating_A  Rating_A+  \
# 0                  8.1724                      4.4530     False      False
# 1                 22.0354                     21.8765     False      False
# 2                 13.6376                      9.6494     False      False
# 3                  9.6412                      5.1018     False      False
# 4                 11.1256                      8.1844      True      False
#
#    Rating_A-  Rating_AA  Rating_AA+  ...  Rating_BBB  Rating_BBB+  \
# 0       True      False       False  ...       False        False
# 1      False      False       False  ...       False        False
# 2      False      False       False  ...       False        False
# 3      False      False       False  ...       False        False
# 4      False      False       False  ...       False        False
#
#    Rating_BBB-  Rating_C  Rating_CC  Rating_CC+  Rating_CCC  Rating_CCC+  \
# 0        False     False      False       False       False        False
# 1        False     False      False       False       False        False
# 2         True     False      False       False       False        False
# 3        False     False      False       False       False        False
# 4        False     False      False       False       False        False
#
#    Rating_CCC-  Rating_D
# 0        False     False
# 1        False     False
# 2        False     False
# 3        False     False
# 4        False     False
#
# [5 rows x 28 columns]

# %%
reduced_df.head()
# Out:
#   Rating  Binary Rating  Debt/Equity Ratio  Net Profit Margin  \
# 0     A-              1             0.8847             8.3224
# 1    AAA              1             0.0073            13.5690
# 2   BBB-              1             0.4255             2.1418
# 3    AA-              1             0.9491             9.0246
# 4      A              1             0.4036             0.6518
#
#    ROE - Return On Equity  ROI - Return On Investment
# 0                  8.1724                      4.4530
# 1                 22.0354                     21.8765
# 2                 13.6376                      9.6494
# 3                  9.6412                      5.1018
# 4                 11.1256                      8.1844

# %%
# Split our preprocessed data into our features and target arrays
X = reduced_numeric.drop(['Binary Rating'], axis=1)
y = reduced_numeric['Binary Rating']

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
reduced_numeric.head()
# Out:
#    Binary Rating  Debt/Equity Ratio  Net Profit Margin  \
# 0              1             0.8847             8.3224
# 1              1             0.0073            13.5690
# 2              1             0.4255             2.1418
# 3              1             0.9491             9.0246
# 4              1             0.4036             0.6518
#
#    ROE - Return On Equity  ROI - Return On Investment  Rating_A  Rating_A+  \
# 0                  8.1724                      4.4530     False      False
# 1                 22.0354                     21.8765     False      False
# 2                 13.6376                      9.6494     False      False
# 3                  9.6412                      5.1018     False      False
# 4                 11.1256                      8.1844      True      False
#
#    Rating_A-  Rating_AA  Rating_AA+  ...  Rating_BBB  Rating_BBB+  \
# 0       True      False       False  ...       False        False
# 1      False      False       False  ...       False        False
# 2      False      False       False  ...       False        False
# 3      False      False       False  ...       False        False
# 4      False      False       False  ...       False        False
#
#    Rating_BBB-  Rating_C  Rating_CC  Rating_CC+  Rating_CCC  Rating_CCC+  \
# 0        False     False      False       False       False        False
# 1        False     False      False       False       False        False
# 2         True     False      False       False       False        False
# 3        False     False      False       False       False        False
# 4        False     False      False       False       False        False
#
#    Rating_CCC-  Rating_D
# 0        False     False
# 1        False     False
# 2        False     False
# 3        False     False
# 4        False     False
#
# [5 rows x 28 columns]

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 4
hidden_nodes_layer2 = 3
hidden_nodes_layer3 = 2

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1,
             input_dim=number_input_features, activation="relu"))

# # Second hidden layer
# nn.add(tf.keras.layers.Dense(
#     units=hidden_nodes_layer2, activation="relu"))

# # Third hidden layer
# nn.add(tf.keras.layers.Dense(
#     units=hidden_nodes_layer3, activation="sigmoid"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 4)                 112
#
#  dense_1 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 117
# Trainable params: 117
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the model
# Used code from https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/ModelCheckpoint
# and from https://stackoverflow.com/questions/44886509/keras-save-checkpoints

EPOCHS = 20
checkpoint_filepath = '../models/model2/checkpoints/weights.epoch_{epoch:02d}.hdf5'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_freq=5,
    verbose=True)

# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
fit_model = nn.fit(X_train_scaled, y_train, epochs=EPOCHS, callbacks=[model_checkpoint_callback])
# Out:
# Epoch 1/20
# 2024-03-14 21:08:37.653479: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
#   1/183 [..............................] - ETA: 56s - loss: 0.5841 - accuracy: 0.6875
# Epoch 1: saving model to ../models/model2/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model2/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model2/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model2/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model2/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model2/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model2/checkpoints/weights.epoch_01.hdf5
#  37/183 [=====>........................] - ETA: 0s - loss: 0.6866 - accuracy: 0.6436
# Epoch 1: saving model to ../models/model2/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model2/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model2/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model2/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model2/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model2/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model2/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model2/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model2/checkpoints/weights.epoch_01.hdf5
#  80/183 [============>.................] - ETA: 0s - loss: 0.6457 - accuracy: 0.6848
# Epoch 1: saving model to ../models/model2/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model2/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model2/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model2/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model2/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model2/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model2/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model2/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model2/checkpoints/weights.epoch_01.hdf5
# 125/183 [===================>..........] - ETA: 0s - loss: 0.6044 - accuracy: 0.7265
# Epoch 1: saving model to ../models/model2/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model2/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model2/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model2/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model2/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model2/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model2/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model2/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model2/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model2/checkpoints/weights.epoch_01.hdf5
# 175/183 [===========================>..] - ETA: 0s - loss: 0.5707 - accuracy: 0.7677
# Epoch 1: saving model to ../models/model2/checkpoints/weights.epoch_01.hdf5
# 183/183 [==============================] - 1s 1ms/step - loss: 0.5663 - accuracy: 0.7743
# Epoch 2/20
#   1/183 [..............................] - ETA: 0s - loss: 0.4322 - accuracy: 0.9375
# Epoch 2: saving model to ../models/model2/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model2/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model2/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model2/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model2/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model2/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model2/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model2/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model2/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model2/checkpoints/weights.epoch_02.hdf5
#  49/183 [=======>......................] - ETA: 0s - loss: 0.4198 - accuracy: 0.9273
# Epoch 2: saving model to ../models/model2/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model2/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model2/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model2/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model2/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model2/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model2/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model2/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model2/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model2/checkpoints/weights.epoch_02.hdf5
#  98/183 [===============>..............] - ETA: 0s - loss: 0.3832 - accuracy: 0.9362
# Epoch 2: saving model to ../models/model2/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model2/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model2/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model2/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model2/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model2/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model2/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model2/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model2/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model2/checkpoints/weights.epoch_02.hdf5
# 151/183 [=======================>......] - ETA: 0s - loss: 0.3602 - accuracy: 0.9327
# Epoch 2: saving model to ../models/model2/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model2/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model2/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model2/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model2/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model2/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model2/checkpoints/weights.epoch_02.hdf5
# 183/183 [==============================] - 0s 1ms/step - loss: 0.3419 - accuracy: 0.9392
# Epoch 3/20
#   1/183 [..............................] - ETA: 0s - loss: 0.2034 - accuracy: 1.0000
# Epoch 3: saving model to ../models/model2/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model2/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model2/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model2/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model2/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model2/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model2/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model2/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model2/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model2/checkpoints/weights.epoch_03.hdf5
#  49/183 [=======>......................] - ETA: 0s - loss: 0.2250 - accuracy: 0.9745
# Epoch 3: saving model to ../models/model2/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model2/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model2/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model2/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model2/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model2/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model2/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model2/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model2/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model2/checkpoints/weights.epoch_03.hdf5
#  99/183 [===============>..............] - ETA: 0s - loss: 0.2133 - accuracy: 0.9782
# Epoch 3: saving model to ../models/model2/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model2/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model2/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model2/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model2/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model2/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model2/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model2/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model2/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model2/checkpoints/weights.epoch_03.hdf5
# 151/183 [=======================>......] - ETA: 0s - loss: 0.1962 - accuracy: 0.9797
# Epoch 3: saving model to ../models/model2/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model2/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model2/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model2/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model2/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model2/checkpoints/weights.epoch_03.hdf5
# 183/183 [==============================] - 0s 999us/step - loss: 0.1868 - accuracy: 0.9822
# Epoch 4/20
#
# Epoch 4: saving model to ../models/model2/checkpoints/weights.epoch_04.hdf5
#   1/183 [..............................] - ETA: 0s - loss: 0.1384 - accuracy: 1.0000
# Epoch 4: saving model to ../models/model2/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model2/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model2/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model2/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model2/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model2/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model2/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model2/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model2/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model2/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model2/checkpoints/weights.epoch_04.hdf5
#  56/183 [========>.....................] - ETA: 0s - loss: 0.1335 - accuracy: 0.9955
# Epoch 4: saving model to ../models/model2/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model2/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model2/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model2/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model2/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model2/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model2/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model2/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model2/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model2/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model2/checkpoints/weights.epoch_04.hdf5
# 111/183 [=================>............] - ETA: 0s - loss: 0.1209 - accuracy: 0.9958
# Epoch 4: saving model to ../models/model2/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model2/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model2/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model2/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model2/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model2/checkpoints/weights.epoch_04.hdf5
# 142/183 [======================>.......] - ETA: 0s - loss: 0.1168 - accuracy: 0.9963
# Epoch 4: saving model to ../models/model2/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model2/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model2/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model2/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model2/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model2/checkpoints/weights.epoch_04.hdf5
# 175/183 [===========================>..] - ETA: 0s - loss: 0.1142 - accuracy: 0.9964
# Epoch 4: saving model to ../models/model2/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model2/checkpoints/weights.epoch_04.hdf5
# 183/183 [==============================] - 0s 1ms/step - loss: 0.1126 - accuracy: 0.9966
# Epoch 5/20
#   1/183 [..............................] - ETA: 0s - loss: 0.0891 - accuracy: 1.0000
# Epoch 5: saving model to ../models/model2/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model2/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model2/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model2/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model2/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model2/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model2/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model2/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model2/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model2/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model2/checkpoints/weights.epoch_05.hdf5
#  53/183 [=======>......................] - ETA: 0s - loss: 0.0956 - accuracy: 0.9965
# Epoch 5: saving model to ../models/model2/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model2/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model2/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model2/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model2/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model2/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model2/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model2/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model2/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model2/checkpoints/weights.epoch_05.hdf5
# 107/183 [================>.............] - ETA: 0s - loss: 0.0870 - accuracy: 0.9968
# Epoch 5: saving model to ../models/model2/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model2/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model2/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model2/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model2/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model2/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model2/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model2/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model2/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model2/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model2/checkpoints/weights.epoch_05.hdf5
# 158/183 [========================>.....] - ETA: 0s - loss: 0.0811 - accuracy: 0.9974
# Epoch 5: saving model to ../models/model2/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model2/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model2/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model2/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model2/checkpoints/weights.epoch_05.hdf5
# 183/183 [==============================] - 0s 966us/step - loss: 0.0794 - accuracy: 0.9971
# Epoch 6/20
#   1/183 [..............................] - ETA: 0s - loss: 0.1391 - accuracy: 0.9688
# Epoch 6: saving model to ../models/model2/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model2/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model2/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model2/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model2/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model2/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model2/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model2/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model2/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model2/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model2/checkpoints/weights.epoch_06.hdf5
#  55/183 [========>.....................] - ETA: 0s - loss: 0.0594 - accuracy: 0.9994
# Epoch 6: saving model to ../models/model2/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model2/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model2/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model2/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model2/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model2/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model2/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model2/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model2/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model2/checkpoints/weights.epoch_06.hdf5
# 107/183 [================>.............] - ETA: 0s - loss: 0.0621 - accuracy: 0.9974
# Epoch 6: saving model to ../models/model2/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model2/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model2/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model2/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model2/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model2/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model2/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model2/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model2/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model2/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model2/checkpoints/weights.epoch_06.hdf5
# 160/183 [=========================>....] - ETA: 0s - loss: 0.0620 - accuracy: 0.9973
# Epoch 6: saving model to ../models/model2/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model2/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model2/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model2/checkpoints/weights.epoch_06.hdf5
# 183/183 [==============================] - 0s 959us/step - loss: 0.0621 - accuracy: 0.9973
# Epoch 7/20
#   1/183 [..............................] - ETA: 0s - loss: 0.0902 - accuracy: 1.0000
# Epoch 7: saving model to ../models/model2/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model2/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model2/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model2/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model2/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model2/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model2/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model2/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model2/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model2/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model2/checkpoints/weights.epoch_07.hdf5
#  52/183 [=======>......................] - ETA: 0s - loss: 0.0548 - accuracy: 0.9976
# Epoch 7: saving model to ../models/model2/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model2/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model2/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model2/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model2/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model2/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model2/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model2/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model2/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model2/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model2/checkpoints/weights.epoch_07.hdf5
# 107/183 [================>.............] - ETA: 0s - loss: 0.0533 - accuracy: 0.9971
# Epoch 7: saving model to ../models/model2/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model2/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model2/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model2/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model2/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model2/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model2/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model2/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model2/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model2/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model2/checkpoints/weights.epoch_07.hdf5
# 162/183 [=========================>....] - ETA: 0s - loss: 0.0516 - accuracy: 0.9975
# Epoch 7: saving model to ../models/model2/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model2/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model2/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model2/checkpoints/weights.epoch_07.hdf5
# 183/183 [==============================] - 0s 949us/step - loss: 0.0512 - accuracy: 0.9974
# Epoch 8/20
#   1/183 [..............................] - ETA: 0s - loss: 0.0256 - accuracy: 1.0000
# Epoch 8: saving model to ../models/model2/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model2/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model2/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model2/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model2/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model2/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model2/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model2/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model2/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model2/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model2/checkpoints/weights.epoch_08.hdf5
#  54/183 [=======>......................] - ETA: 0s - loss: 0.0473 - accuracy: 0.9977
# Epoch 8: saving model to ../models/model2/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model2/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model2/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model2/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model2/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model2/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model2/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model2/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model2/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model2/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model2/checkpoints/weights.epoch_08.hdf5
# 109/183 [================>.............] - ETA: 0s - loss: 0.0464 - accuracy: 0.9971
# Epoch 8: saving model to ../models/model2/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model2/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model2/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model2/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model2/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model2/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model2/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model2/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model2/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model2/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model2/checkpoints/weights.epoch_08.hdf5
# 164/183 [=========================>....] - ETA: 0s - loss: 0.0447 - accuracy: 0.9975
# Epoch 8: saving model to ../models/model2/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model2/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model2/checkpoints/weights.epoch_08.hdf5
# 183/183 [==============================] - 0s 943us/step - loss: 0.0442 - accuracy: 0.9974
# Epoch 9/20
#
# Epoch 9: saving model to ../models/model2/checkpoints/weights.epoch_09.hdf5
#   1/183 [..............................] - ETA: 0s - loss: 0.0339 - accuracy: 1.0000
# Epoch 9: saving model to ../models/model2/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model2/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model2/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model2/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model2/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model2/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model2/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model2/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model2/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model2/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model2/checkpoints/weights.epoch_09.hdf5
#  56/183 [========>.....................] - ETA: 0s - loss: 0.0400 - accuracy: 0.9989
# Epoch 9: saving model to ../models/model2/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model2/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model2/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model2/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model2/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model2/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model2/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model2/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model2/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model2/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model2/checkpoints/weights.epoch_09.hdf5
# 111/183 [=================>............] - ETA: 0s - loss: 0.0393 - accuracy: 0.9983
# Epoch 9: saving model to ../models/model2/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model2/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model2/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model2/checkpoints/weights.epoch_09.hdf5
# 133/183 [====================>.........] - ETA: 0s - loss: 0.0394 - accuracy: 0.9979
# Epoch 9: saving model to ../models/model2/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model2/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model2/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model2/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model2/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model2/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model2/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model2/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model2/checkpoints/weights.epoch_09.hdf5
# 176/183 [===========================>..] - ETA: 0s - loss: 0.0396 - accuracy: 0.9979
# Epoch 9: saving model to ../models/model2/checkpoints/weights.epoch_09.hdf5
# 183/183 [==============================] - 0s 1ms/step - loss: 0.0392 - accuracy: 0.9979
# Epoch 10/20
#   1/183 [..............................] - ETA: 0s - loss: 0.0192 - accuracy: 1.0000
# Epoch 10: saving model to ../models/model2/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model2/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model2/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model2/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model2/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model2/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model2/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model2/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model2/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model2/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model2/checkpoints/weights.epoch_10.hdf5
#  56/183 [========>.....................] - ETA: 0s - loss: 0.0377 - accuracy: 0.9978
# Epoch 10: saving model to ../models/model2/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model2/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model2/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model2/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model2/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model2/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model2/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model2/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model2/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model2/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model2/checkpoints/weights.epoch_10.hdf5
# 108/183 [================>.............] - ETA: 0s - loss: 0.0366 - accuracy: 0.9977
# Epoch 10: saving model to ../models/model2/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model2/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model2/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model2/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model2/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model2/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model2/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model2/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model2/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model2/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model2/checkpoints/weights.epoch_10.hdf5
# 163/183 [=========================>....] - ETA: 0s - loss: 0.0348 - accuracy: 0.9981
# Epoch 10: saving model to ../models/model2/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model2/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model2/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model2/checkpoints/weights.epoch_10.hdf5
# 183/183 [==============================] - 0s 958us/step - loss: 0.0354 - accuracy: 0.9979
# Epoch 11/20
#   1/183 [..............................] - ETA: 0s - loss: 0.0396 - accuracy: 1.0000
# Epoch 11: saving model to ../models/model2/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model2/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model2/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model2/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model2/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model2/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model2/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model2/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model2/checkpoints/weights.epoch_11.hdf5
#  45/183 [======>.......................] - ETA: 0s - loss: 0.0320 - accuracy: 1.0000
# Epoch 11: saving model to ../models/model2/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model2/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model2/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model2/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model2/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model2/checkpoints/weights.epoch_11.hdf5
#  75/183 [===========>..................] - ETA: 0s - loss: 0.0317 - accuracy: 0.9987
# Epoch 11: saving model to ../models/model2/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model2/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model2/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model2/checkpoints/weights.epoch_11.hdf5
#  99/183 [===============>..............] - ETA: 0s - loss: 0.0310 - accuracy: 0.9987
# Epoch 11: saving model to ../models/model2/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model2/checkpoints/weights.epoch_11.hdf5
# 105/183 [================>.............] - ETA: 0s - loss: 0.0310 - accuracy: 0.9988
# Epoch 11: saving model to ../models/model2/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model2/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model2/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model2/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model2/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model2/checkpoints/weights.epoch_11.hdf5
# 136/183 [=====================>........] - ETA: 0s - loss: 0.0328 - accuracy: 0.9982
# Epoch 11: saving model to ../models/model2/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model2/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model2/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model2/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model2/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model2/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model2/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model2/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model2/checkpoints/weights.epoch_11.hdf5
# 183/183 [==============================] - 0s 2ms/step - loss: 0.0323 - accuracy: 0.9981
# Epoch 12/20
#   1/183 [..............................] - ETA: 0s - loss: 0.0250 - accuracy: 1.0000
# Epoch 12: saving model to ../models/model2/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model2/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model2/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model2/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model2/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model2/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model2/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model2/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model2/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model2/checkpoints/weights.epoch_12.hdf5
#  47/183 [======>.......................] - ETA: 0s - loss: 0.0295 - accuracy: 0.9980
# Epoch 12: saving model to ../models/model2/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model2/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model2/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model2/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model2/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model2/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model2/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model2/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model2/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model2/checkpoints/weights.epoch_12.hdf5
#  97/183 [==============>...............] - ETA: 0s - loss: 0.0302 - accuracy: 0.9981
# Epoch 12: saving model to ../models/model2/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model2/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model2/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model2/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model2/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model2/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model2/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model2/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model2/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model2/checkpoints/weights.epoch_12.hdf5
# 149/183 [=======================>......] - ETA: 0s - loss: 0.0295 - accuracy: 0.9979
# Epoch 12: saving model to ../models/model2/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model2/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model2/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model2/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model2/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model2/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model2/checkpoints/weights.epoch_12.hdf5
# 183/183 [==============================] - 0s 1ms/step - loss: 0.0298 - accuracy: 0.9981
# Epoch 13/20
#   1/183 [..............................] - ETA: 0s - loss: 0.0331 - accuracy: 1.0000
# Epoch 13: saving model to ../models/model2/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model2/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model2/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model2/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model2/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model2/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model2/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model2/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model2/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model2/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model2/checkpoints/weights.epoch_13.hdf5
#  54/183 [=======>......................] - ETA: 0s - loss: 0.0304 - accuracy: 0.9983
# Epoch 13: saving model to ../models/model2/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model2/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model2/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model2/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model2/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model2/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model2/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model2/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model2/checkpoints/weights.epoch_13.hdf5
#  99/183 [===============>..............] - ETA: 0s - loss: 0.0272 - accuracy: 0.9984
# Epoch 13: saving model to ../models/model2/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model2/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model2/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model2/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model2/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model2/checkpoints/weights.epoch_13.hdf5
# 130/183 [====================>.........] - ETA: 0s - loss: 0.0279 - accuracy: 0.9978
# Epoch 13: saving model to ../models/model2/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model2/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model2/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model2/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model2/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model2/checkpoints/weights.epoch_13.hdf5
# 159/183 [=========================>....] - ETA: 0s - loss: 0.0280 - accuracy: 0.9980
# Epoch 13: saving model to ../models/model2/checkpoints/weights.epoch_13.hdf5
# 164/183 [=========================>....] - ETA: 0s - loss: 0.0280 - accuracy: 0.9981
# Epoch 13: saving model to ../models/model2/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model2/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model2/checkpoints/weights.epoch_13.hdf5
# 183/183 [==============================] - 0s 2ms/step - loss: 0.0277 - accuracy: 0.9981
# Epoch 14/20
#
# Epoch 14: saving model to ../models/model2/checkpoints/weights.epoch_14.hdf5
#   1/183 [..............................] - ETA: 1s - loss: 0.0217 - accuracy: 1.0000
# Epoch 14: saving model to ../models/model2/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model2/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model2/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model2/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model2/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model2/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model2/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model2/checkpoints/weights.epoch_14.hdf5
#  41/183 [=====>........................] - ETA: 0s - loss: 0.0263 - accuracy: 0.9992
# Epoch 14: saving model to ../models/model2/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model2/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model2/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model2/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model2/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model2/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model2/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model2/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model2/checkpoints/weights.epoch_14.hdf5
#  86/183 [=============>................] - ETA: 0s - loss: 0.0246 - accuracy: 0.9989
# Epoch 14: saving model to ../models/model2/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model2/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model2/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model2/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model2/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model2/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model2/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model2/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model2/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model2/checkpoints/weights.epoch_14.hdf5
# 136/183 [=====================>........] - ETA: 0s - loss: 0.0249 - accuracy: 0.9984
# Epoch 14: saving model to ../models/model2/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model2/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model2/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model2/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model2/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model2/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model2/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model2/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model2/checkpoints/weights.epoch_14.hdf5
# 183/183 [==============================] - 0s 1ms/step - loss: 0.0258 - accuracy: 0.9981
# Epoch 15/20
#   1/183 [..............................] - ETA: 0s - loss: 0.0200 - accuracy: 1.0000
# Epoch 15: saving model to ../models/model2/checkpoints/weights.epoch_15.hdf5
#
# Epoch 15: saving model to ../models/model2/checkpoints/weights.epoch_15.hdf5
#
# Epoch 15: saving model to ../models/model2/checkpoints/weights.epoch_15.hdf5
#
# Epoch 15: saving model to ../models/model2/checkpoints/weights.epoch_15.hdf5
#
# Epoch 15: saving model to ../models/model2/checkpoints/weights.epoch_15.hdf5
#
# Epoch 15: saving model to ../models/model2/checkpoints/weights.epoch_15.hdf5
#
# Epoch 15: saving model to ../models/model2/checkpoints/weights.epoch_15.hdf5
#
# Epoch 15: saving model to ../models/model2/checkpoints/weights.epoch_15.hdf5
#
# Epoch 15: saving model to ../models/model2/checkpoints/weights.epoch_15.hdf5
#
# Epoch 15: saving model to ../models/model2/checkpoints/weights.epoch_15.hdf5
#  50/183 [=======>......................] - ETA: 0s - loss: 0.0297 - accuracy: 0.9981
# Epoch 15: saving model to ../models/model2/checkpoints/weights.epoch_15.hdf5
#
# Epoch 15: saving model to ../models/model2/checkpoints/weights.epoch_15.hdf5
#
# Epoch 15: saving model to ../models/model2/checkpoints/weights.epoch_15.hdf5
#
# Epoch 15: saving model to ../models/model2/checkpoints/weights.epoch_15.hdf5
#
# Epoch 15: saving model to ../models/model2/checkpoints/weights.epoch_15.hdf5
#
# Epoch 15: saving model to ../models/model2/checkpoints/weights.epoch_15.hdf5
#
# Epoch 15: saving model to ../models/model2/checkpoints/weights.epoch_15.hdf5
#
# ...
# Epoch 16: saving model to ../models/model2/checkpoints/weights.epoch_16.hdf5
#
# Epoch 16: saving model to ../models/model2/checkpoints/weights.epoch_16.hdf5
#
# Epoch 16: saving model to ../models/model2/checkpoints/weights.epoch_16.hdf5
#
# Epoch 16: saving model to ../models/model2/checkpoints/weights.epoch_16.hdf5
# 114/183 [=================>............] - ETA: 0s - loss: 0.0240 - accuracy: 0.9978
# Epoch 16: saving model to ../models/model2/checkpoints/weights.epoch_16.hdf5
#
# Epoch 16: saving model to ../models/model2/checkpoints/weights.epoch_16.hdf5
#
# Epoch 16: saving model to ../models/model2/checkpoints/weights.epoch_16.hdf5
# 125/183 [===================>..........] - ETA: 0s - loss: 0.0238 - accuracy: 0.9980
# Epoch 16: saving model to ../models/model2/checkpoints/weights.epoch_16.hdf5
#
# Epoch 16: saving model to ../models/model2/checkpoints/weights.epoch_16.hdf5
#
# Epoch 16: saving model to ../models/model2/checkpoints/weights.epoch_16.hdf5
#
# Epoch 16: saving model to ../models/model2/checkpoints/weights.epoch_16.hdf5
#
# Epoch 16: saving model to ../models/model2/checkpoints/weights.epoch_16.hdf5
#
# Epoch 16: saving model to ../models/model2/checkpoints/weights.epoch_16.hdf5
#
# Epoch 16: saving model to ../models/model2/checkpoints/weights.epoch_16.hdf5
#
# Epoch 16: saving model to ../models/model2/checkpoints/weights.epoch_16.hdf5
#
# Epoch 16: saving model to ../models/model2/checkpoints/weights.epoch_16.hdf5
#
# Epoch 16: saving model to ../models/model2/checkpoints/weights.epoch_16.hdf5
# 175/183 [===========================>..] - ETA: 0s - loss: 0.0227 - accuracy: 0.9980
# Epoch 16: saving model to ../models/model2/checkpoints/weights.epoch_16.hdf5
# 183/183 [==============================] - 0s 2ms/step - loss: 0.0226 - accuracy: 0.9981
# Epoch 17/20
#   1/183 [..............................] - ETA: 0s - loss: 0.0090 - accuracy: 1.0000
# Epoch 17: saving model to ../models/model2/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model2/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model2/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model2/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model2/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model2/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model2/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model2/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model2/checkpoints/weights.epoch_17.hdf5
#  43/183 [======>.......................] - ETA: 0s - loss: 0.0187 - accuracy: 0.9985
# Epoch 17: saving model to ../models/model2/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model2/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model2/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model2/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model2/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model2/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model2/checkpoints/weights.epoch_17.hdf5
#  77/183 [===========>..................] - ETA: 0s - loss: 0.0213 - accuracy: 0.9980
# Epoch 17: saving model to ../models/model2/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model2/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model2/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model2/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model2/checkpoints/weights.epoch_17.hdf5
# 102/183 [===============>..............] - ETA: 0s - loss: 0.0227 - accuracy: 0.9979
# Epoch 17: saving model to ../models/model2/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model2/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model2/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model2/checkpoints/weights.epoch_17.hdf5
# 125/183 [===================>..........] - ETA: 0s - loss: 0.0221 - accuracy: 0.9983
# Epoch 17: saving model to ../models/model2/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model2/checkpoints/weights.epoch_17.hdf5
# 135/183 [=====================>........] - ETA: 0s - loss: 0.0216 - accuracy: 0.9984
# Epoch 17: saving model to ../models/model2/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model2/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model2/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model2/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model2/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model2/checkpoints/weights.epoch_17.hdf5
# 162/183 [=========================>....] - ETA: 0s - loss: 0.0217 - accuracy: 0.9981
# Epoch 17: saving model to ../models/model2/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model2/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model2/checkpoints/weights.epoch_17.hdf5
#
# Epoch 17: saving model to ../models/model2/checkpoints/weights.epoch_17.hdf5
# 183/183 [==============================] - 0s 2ms/step - loss: 0.0212 - accuracy: 0.9981
# Epoch 18/20
#   1/183 [..............................] - ETA: 0s - loss: 0.0083 - accuracy: 1.0000
# Epoch 18: saving model to ../models/model2/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model2/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model2/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model2/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model2/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model2/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model2/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model2/checkpoints/weights.epoch_18.hdf5
#  39/183 [=====>........................] - ETA: 0s - loss: 0.0178 - accuracy: 0.9984
# Epoch 18: saving model to ../models/model2/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model2/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model2/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model2/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model2/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model2/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model2/checkpoints/weights.epoch_18.hdf5
#  74/183 [===========>..................] - ETA: 0s - loss: 0.0195 - accuracy: 0.9979
# Epoch 18: saving model to ../models/model2/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model2/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model2/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model2/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model2/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model2/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model2/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model2/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model2/checkpoints/weights.epoch_18.hdf5
# 121/183 [==================>...........] - ETA: 0s - loss: 0.0209 - accuracy: 0.9977
# Epoch 18: saving model to ../models/model2/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model2/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model2/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model2/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model2/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model2/checkpoints/weights.epoch_18.hdf5
# 152/183 [=======================>......] - ETA: 0s - loss: 0.0198 - accuracy: 0.9981
# Epoch 18: saving model to ../models/model2/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model2/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model2/checkpoints/weights.epoch_18.hdf5
# 164/183 [=========================>....] - ETA: 0s - loss: 0.0195 - accuracy: 0.9983
# Epoch 18: saving model to ../models/model2/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model2/checkpoints/weights.epoch_18.hdf5
#
# Epoch 18: saving model to ../models/model2/checkpoints/weights.epoch_18.hdf5
# 183/183 [==============================] - 0s 2ms/step - loss: 0.0199 - accuracy: 0.9981
# Epoch 19/20
#
# Epoch 19: saving model to ../models/model2/checkpoints/weights.epoch_19.hdf5
#   1/183 [..............................] - ETA: 1s - loss: 0.0079 - accuracy: 1.0000
# Epoch 19: saving model to ../models/model2/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model2/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model2/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model2/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model2/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model2/checkpoints/weights.epoch_19.hdf5
#  32/183 [====>.........................] - ETA: 0s - loss: 0.0228 - accuracy: 0.9980
# Epoch 19: saving model to ../models/model2/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model2/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model2/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model2/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model2/checkpoints/weights.epoch_19.hdf5
#  56/183 [========>.....................] - ETA: 0s - loss: 0.0208 - accuracy: 0.9978
# Epoch 19: saving model to ../models/model2/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model2/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model2/checkpoints/weights.epoch_19.hdf5
#  75/183 [===========>..................] - ETA: 0s - loss: 0.0197 - accuracy: 0.9983
# Epoch 19: saving model to ../models/model2/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model2/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model2/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model2/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model2/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model2/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model2/checkpoints/weights.epoch_19.hdf5
# 106/183 [================>.............] - ETA: 0s - loss: 0.0189 - accuracy: 0.9982
# Epoch 19: saving model to ../models/model2/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model2/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model2/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model2/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model2/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model2/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model2/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model2/checkpoints/weights.epoch_19.hdf5
# 146/183 [======================>.......] - ETA: 0s - loss: 0.0194 - accuracy: 0.9979
# Epoch 19: saving model to ../models/model2/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model2/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model2/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model2/checkpoints/weights.epoch_19.hdf5
# 170/183 [==========================>...] - ETA: 0s - loss: 0.0188 - accuracy: 0.9982
# Epoch 19: saving model to ../models/model2/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model2/checkpoints/weights.epoch_19.hdf5
#
# Epoch 19: saving model to ../models/model2/checkpoints/weights.epoch_19.hdf5
# 183/183 [==============================] - 0s 2ms/step - loss: 0.0188 - accuracy: 0.9981
# Epoch 20/20
#   1/183 [..............................] - ETA: 0s - loss: 0.0258 - accuracy: 1.0000
# Epoch 20: saving model to ../models/model2/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model2/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model2/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model2/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model2/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model2/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model2/checkpoints/weights.epoch_20.hdf5
#  33/183 [====>.........................] - ETA: 0s - loss: 0.0160 - accuracy: 0.9981
# Epoch 20: saving model to ../models/model2/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model2/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model2/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model2/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model2/checkpoints/weights.epoch_20.hdf5
#  59/183 [========>.....................] - ETA: 0s - loss: 0.0194 - accuracy: 0.9974
# Epoch 20: saving model to ../models/model2/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model2/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model2/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model2/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model2/checkpoints/weights.epoch_20.hdf5
#  83/183 [============>.................] - ETA: 0s - loss: 0.0205 - accuracy: 0.9966
# Epoch 20: saving model to ../models/model2/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model2/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model2/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model2/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model2/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model2/checkpoints/weights.epoch_20.hdf5
# 113/183 [=================>............] - ETA: 0s - loss: 0.0193 - accuracy: 0.9972
# Epoch 20: saving model to ../models/model2/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model2/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model2/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model2/checkpoints/weights.epoch_20.hdf5
# 133/183 [====================>.........] - ETA: 0s - loss: 0.0191 - accuracy: 0.9977
# Epoch 20: saving model to ../models/model2/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model2/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model2/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model2/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model2/checkpoints/weights.epoch_20.hdf5
# 159/183 [=========================>....] - ETA: 0s - loss: 0.0186 - accuracy: 0.9978
# Epoch 20: saving model to ../models/model2/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model2/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model2/checkpoints/weights.epoch_20.hdf5
# 173/183 [===========================>..] - ETA: 0s - loss: 0.0180 - accuracy: 0.9980
# Epoch 20: saving model to ../models/model2/checkpoints/weights.epoch_20.hdf5
#
# Epoch 20: saving model to ../models/model2/checkpoints/weights.epoch_20.hdf5
# 183/183 [==============================] - 0s 2ms/step - loss: 0.0178 - accuracy: 0.9981

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 61/61 - 0s - loss: 0.0192 - accuracy: 0.9964 - 89ms/epoch - 1ms/step
# Loss: 0.019173936918377876, Accuracy: 0.9964139461517334

# %%
# Export our model to HDF5 file
nn.save('../models/model2/model.h5')
