# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint
import pandas as pd
import sqlite3

# %%
connection = sqlite3.connect('../data/db.sqlite')

# Import DB into pandas dataframe
df = pd.read_sql_query("SELECT * FROM pca", connection)

connection.close()

df.head()
# Out:
#                       Corporation            PC1  Binary Rating          PC2  \
# 0       American States Water Co.  319741.641714              1   801.328232
# 1  Automatic Data Processing Inc. -728490.657302              1  3519.620476
# 2                      Avnet Inc. -728303.285091              1  1210.233135
# 3    California Water Service Co.  298039.642473              1   807.233946
# 4            Cardinal Health Inc.  -15790.296680              1  1073.498944
#
#    Cluster
# 0        0
# 1        1
# 2        1
# 3        0
# 4        0

# %%
df.columns
# Out:
# Index(['Corporation', 'PC1', 'Binary Rating', 'PC2', 'Cluster'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7805 entries, 0 to 7804
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Corporation    7805 non-null   object
#  1   PC1            7805 non-null   float64
#  2   Binary Rating  7805 non-null   int64
#  3   PC2            7805 non-null   float64
#  4   Cluster        7805 non-null   int64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 305.0+ KB

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
reduced_df = df.drop(columns=['Corporation'])
reduced_df.head()
# Out:
#              PC1  Binary Rating          PC2  Cluster
# 0  319741.641714              1   801.328232        0
# 1 -728490.657302              1  3519.620476        1
# 2 -728303.285091              1  1210.233135        1
# 3  298039.642473              1   807.233946        0
# 4  -15790.296680              1  1073.498944        0

# %%
# Determine the number of unique values in each column.
reduced_df.nunique()
# Out:
# PC1              4552
# Binary Rating       2
# PC2              4552
# Cluster             3
# dtype: int64

# %%
reduced_df.columns
# Out:
# Index(['PC1', 'Binary Rating', 'PC2', 'Cluster'], dtype='object')

# %%
# Used code from https://stackoverflow.com/questions/14247586/how-to-select-rows-with-one-or-more-nulls-from-a-pandas-dataframe-without-listin
# Look for nulls
def nans(df): return df[df.isnull().any(axis=1)]
nans(reduced_df)
# Out:
# Empty DataFrame
# Columns: [PC1, Binary Rating, PC2, Cluster]
# Index: []

# %%
# Checking for NA's
def nans2(df): return df[df.isna().any(axis=1)]
nans2(reduced_df)
# Out:
# Empty DataFrame
# Columns: [PC1, Binary Rating, PC2, Cluster]
# Index: []

# %%
# # Look at APPLICATION_TYPE value counts for binning
# application_counts = reduced_df['APPLICATION_TYPE'].value_counts()
# application_counts

# %%
# # Choose a cutoff value and create a list of application types to be replaced
# # use the variable name `application_types_to_replace`
# application_types_to_replace = list(application_counts[application_counts < 528].index)

# # Replace in dataframe
# for app in application_types_to_replace:
#     reduced_df['APPLICATION_TYPE'] = reduced_df['APPLICATION_TYPE'].replace(app,"Other")

# # Check to make sure binning was successful
# reduced_df['APPLICATION_TYPE'].value_counts()

# %%
# # Look at CLASSIFICATION value counts for binning
# classification_counts = reduced_df['CLASSIFICATION'].value_counts()
# classification_counts

# %%
# # You may find it helpful to look at CLASSIFICATION value counts >1
# class_counts_over1 = classification_counts.loc[classification_counts > 1]
# class_counts_over1

# %%
# # Choose a cutoff value and create a list of classifications to be replaced
# # use the variable name `classifications_to_replace`
# classifications_to_replace = list(classification_counts[classification_counts < 1000].index)

# # Replace in dataframe
# for cls in classifications_to_replace:
#     reduced_df['CLASSIFICATION'] = reduced_df['CLASSIFICATION'].replace(cls,"Other")

# # Check to make sure binning was successful
# reduced_df['CLASSIFICATION'].value_counts()

# %%
# Convert categorical data to numeric with `pd.get_dummies`
reduced_numeric = pd.get_dummies(reduced_df)

# %%
reduced_numeric.head()
# Out:
#              PC1  Binary Rating          PC2  Cluster
# 0  319741.641714              1   801.328232        0
# 1 -728490.657302              1  3519.620476        1
# 2 -728303.285091              1  1210.233135        1
# 3  298039.642473              1   807.233946        0
# 4  -15790.296680              1  1073.498944        0

# %%
reduced_df.head()
# Out:
#              PC1  Binary Rating          PC2  Cluster
# 0  319741.641714              1   801.328232        0
# 1 -728490.657302              1  3519.620476        1
# 2 -728303.285091              1  1210.233135        1
# 3  298039.642473              1   807.233946        0
# 4  -15790.296680              1  1073.498944        0

# %%
# Split our preprocessed data into our features and target arrays
X = reduced_numeric.drop(['Binary Rating'], axis=1)
y = reduced_numeric['Binary Rating']

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
reduced_numeric.head()
# Out:
#              PC1  Binary Rating          PC2  Cluster
# 0  319741.641714              1   801.328232        0
# 1 -728490.657302              1  3519.620476        1
# 2 -728303.285091              1  1210.233135        1
# 3  298039.642473              1   807.233946        0
# 4  -15790.296680              1  1073.498944        0

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train_scaled[0])
# hidden_nodes_layer1 = 3
# hidden_nodes_layer2 = 3
# hidden_nodes_layer3 = 3
# hidden_nodes_layer4 = 2

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=3,
             input_dim=number_input_features, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(
    units=3, activation="relu"))

# # Third hidden layer
# nn.add(tf.keras.layers.Dense(
#     units=3, activation="relu"))

# nn.add(tf.keras.layers.Dense(
#     units=hidden_nodes_layer4, activation="sigmoid"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 3)                 12
#
#  dense_1 (Dense)             (None, 3)                 12
#
#  dense_2 (Dense)             (None, 1)                 4
#
# =================================================================
# Total params: 28
# Trainable params: 28
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the model
# Used code from https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/ModelCheckpoint
# and from https://stackoverflow.com/questions/44886509/keras-save-checkpoints

EPOCHS = 75
checkpoint_filepath = '../models/model6/checkpoints/weights.epoch_{epoch:02d}.hdf5'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_freq=5,
    verbose=True)

# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
fit_model = nn.fit(X_train_scaled, y_train, epochs=EPOCHS, callbacks=[model_checkpoint_callback])
# Out:
# Epoch 1/75
# 2024-03-16 16:12:30.826562: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
#   1/183 [..............................] - ETA: 1:03 - loss: 0.7326 - accuracy: 0.5625
# Epoch 1: saving model to ../models/model6/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model6/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model6/checkpoints/weights.epoch_01.hdf5
#  18/183 [=>............................] - ETA: 0s - loss: 0.7745 - accuracy: 0.3264
# Epoch 1: saving model to ../models/model6/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model6/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model6/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model6/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model6/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model6/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model6/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model6/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model6/checkpoints/weights.epoch_01.hdf5
#  60/183 [========>.....................] - ETA: 0s - loss: 0.7457 - accuracy: 0.3380
# Epoch 1: saving model to ../models/model6/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model6/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model6/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model6/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model6/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model6/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model6/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model6/checkpoints/weights.epoch_01.hdf5
# 103/183 [===============>..............] - ETA: 0s - loss: 0.7264 - accuracy: 0.3896
# Epoch 1: saving model to ../models/model6/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model6/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model6/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model6/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model6/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model6/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model6/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model6/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model6/checkpoints/weights.epoch_01.hdf5
# 145/183 [======================>.......] - ETA: 0s - loss: 0.7116 - accuracy: 0.4601
# Epoch 1: saving model to ../models/model6/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model6/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model6/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model6/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model6/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model6/checkpoints/weights.epoch_01.hdf5
#
# Epoch 1: saving model to ../models/model6/checkpoints/weights.epoch_01.hdf5
# 183/183 [==============================] - 1s 1ms/step - loss: 0.7015 - accuracy: 0.5004
# Epoch 2/75
#   1/183 [..............................] - ETA: 0s - loss: 0.6520 - accuracy: 0.6562
# Epoch 2: saving model to ../models/model6/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model6/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model6/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model6/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model6/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model6/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model6/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model6/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model6/checkpoints/weights.epoch_02.hdf5
#  43/183 [======>.......................] - ETA: 0s - loss: 0.6558 - accuracy: 0.6483
# Epoch 2: saving model to ../models/model6/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model6/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model6/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model6/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model6/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model6/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model6/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model6/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model6/checkpoints/weights.epoch_02.hdf5
#  87/183 [=============>................] - ETA: 0s - loss: 0.6529 - accuracy: 0.6487
# Epoch 2: saving model to ../models/model6/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model6/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model6/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model6/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model6/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model6/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model6/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model6/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model6/checkpoints/weights.epoch_02.hdf5
# 132/183 [====================>.........] - ETA: 0s - loss: 0.6475 - accuracy: 0.6544
# Epoch 2: saving model to ../models/model6/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model6/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model6/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model6/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model6/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model6/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model6/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model6/checkpoints/weights.epoch_02.hdf5
#
# Epoch 2: saving model to ../models/model6/checkpoints/weights.epoch_02.hdf5
# 177/183 [============================>.] - ETA: 0s - loss: 0.6487 - accuracy: 0.6483
# Epoch 2: saving model to ../models/model6/checkpoints/weights.epoch_02.hdf5
# 183/183 [==============================] - 0s 1ms/step - loss: 0.6484 - accuracy: 0.6487
# Epoch 3/75
#   1/183 [..............................] - ETA: 0s - loss: 0.5991 - accuracy: 0.7188
# Epoch 3: saving model to ../models/model6/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model6/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model6/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model6/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model6/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model6/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model6/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model6/checkpoints/weights.epoch_03.hdf5
#  43/183 [======>.......................] - ETA: 0s - loss: 0.6387 - accuracy: 0.6555
# Epoch 3: saving model to ../models/model6/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model6/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model6/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model6/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model6/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model6/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model6/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model6/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model6/checkpoints/weights.epoch_03.hdf5
#  84/183 [============>.................] - ETA: 0s - loss: 0.6396 - accuracy: 0.6540
# Epoch 3: saving model to ../models/model6/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model6/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model6/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model6/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model6/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model6/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model6/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model6/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model6/checkpoints/weights.epoch_03.hdf5
# 129/183 [====================>.........] - ETA: 0s - loss: 0.6372 - accuracy: 0.6543
# Epoch 3: saving model to ../models/model6/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model6/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model6/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model6/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model6/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model6/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model6/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model6/checkpoints/weights.epoch_03.hdf5
# 173/183 [===========================>..] - ETA: 0s - loss: 0.6404 - accuracy: 0.6476
# Epoch 3: saving model to ../models/model6/checkpoints/weights.epoch_03.hdf5
#
# Epoch 3: saving model to ../models/model6/checkpoints/weights.epoch_03.hdf5
# 183/183 [==============================] - 0s 1ms/step - loss: 0.6392 - accuracy: 0.6487
# Epoch 4/75
#
# Epoch 4: saving model to ../models/model6/checkpoints/weights.epoch_04.hdf5
#   1/183 [..............................] - ETA: 0s - loss: 0.6336 - accuracy: 0.6562
# Epoch 4: saving model to ../models/model6/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model6/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model6/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model6/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model6/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model6/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model6/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model6/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model6/checkpoints/weights.epoch_04.hdf5
#  46/183 [======>.......................] - ETA: 0s - loss: 0.6409 - accuracy: 0.6454
# Epoch 4: saving model to ../models/model6/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model6/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model6/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model6/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model6/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model6/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model6/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model6/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model6/checkpoints/weights.epoch_04.hdf5
#  91/183 [=============>................] - ETA: 0s - loss: 0.6307 - accuracy: 0.6573
# Epoch 4: saving model to ../models/model6/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model6/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model6/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model6/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model6/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model6/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model6/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model6/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model6/checkpoints/weights.epoch_04.hdf5
# 136/183 [=====================>........] - ETA: 0s - loss: 0.6337 - accuracy: 0.6517
# Epoch 4: saving model to ../models/model6/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model6/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model6/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model6/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model6/checkpoints/weights.epoch_04.hdf5
# 163/183 [=========================>....] - ETA: 0s - loss: 0.6343 - accuracy: 0.6492
# Epoch 4: saving model to ../models/model6/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model6/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model6/checkpoints/weights.epoch_04.hdf5
#
# Epoch 4: saving model to ../models/model6/checkpoints/weights.epoch_04.hdf5
# 183/183 [==============================] - 0s 1ms/step - loss: 0.6339 - accuracy: 0.6487
# Epoch 5/75
#   1/183 [..............................] - ETA: 0s - loss: 0.5860 - accuracy: 0.6875
# Epoch 5: saving model to ../models/model6/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model6/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model6/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model6/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model6/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model6/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model6/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model6/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model6/checkpoints/weights.epoch_05.hdf5
#  43/183 [======>.......................] - ETA: 0s - loss: 0.6380 - accuracy: 0.6403
# Epoch 5: saving model to ../models/model6/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model6/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model6/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model6/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model6/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model6/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model6/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model6/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model6/checkpoints/weights.epoch_05.hdf5
#  88/183 [=============>................] - ETA: 0s - loss: 0.6320 - accuracy: 0.6445
# Epoch 5: saving model to ../models/model6/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model6/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model6/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model6/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model6/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model6/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model6/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model6/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model6/checkpoints/weights.epoch_05.hdf5
# 133/183 [====================>.........] - ETA: 0s - loss: 0.6273 - accuracy: 0.6518
# Epoch 5: saving model to ../models/model6/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model6/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model6/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model6/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model6/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model6/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model6/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model6/checkpoints/weights.epoch_05.hdf5
#
# Epoch 5: saving model to ../models/model6/checkpoints/weights.epoch_05.hdf5
# 178/183 [============================>.] - ETA: 0s - loss: 0.6284 - accuracy: 0.6499
# Epoch 5: saving model to ../models/model6/checkpoints/weights.epoch_05.hdf5
# 183/183 [==============================] - 0s 1ms/step - loss: 0.6292 - accuracy: 0.6487
# Epoch 6/75
#   1/183 [..............................] - ETA: 0s - loss: 0.6302 - accuracy: 0.6250
# Epoch 6: saving model to ../models/model6/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model6/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model6/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model6/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model6/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model6/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model6/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model6/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model6/checkpoints/weights.epoch_06.hdf5
#  45/183 [======>.......................] - ETA: 0s - loss: 0.6288 - accuracy: 0.6486
# Epoch 6: saving model to ../models/model6/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model6/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model6/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model6/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model6/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model6/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model6/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model6/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model6/checkpoints/weights.epoch_06.hdf5
#  90/183 [=============>................] - ETA: 0s - loss: 0.6177 - accuracy: 0.6601
# Epoch 6: saving model to ../models/model6/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model6/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model6/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model6/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model6/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model6/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model6/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model6/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model6/checkpoints/weights.epoch_06.hdf5
# 135/183 [=====================>........] - ETA: 0s - loss: 0.6240 - accuracy: 0.6525
# Epoch 6: saving model to ../models/model6/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model6/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model6/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model6/checkpoints/weights.epoch_06.hdf5
# 155/183 [========================>.....] - ETA: 0s - loss: 0.6256 - accuracy: 0.6500
# Epoch 6: saving model to ../models/model6/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model6/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model6/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model6/checkpoints/weights.epoch_06.hdf5
#
# Epoch 6: saving model to ../models/model6/checkpoints/weights.epoch_06.hdf5
# 183/183 [==============================] - 0s 1ms/step - loss: 0.6257 - accuracy: 0.6487
# Epoch 7/75
#   1/183 [..............................] - ETA: 0s - loss: 0.5334 - accuracy: 0.7188
# Epoch 7: saving model to ../models/model6/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model6/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model6/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model6/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model6/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model6/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model6/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model6/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model6/checkpoints/weights.epoch_07.hdf5
#  42/183 [=====>........................] - ETA: 0s - loss: 0.6192 - accuracy: 0.6555
# Epoch 7: saving model to ../models/model6/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model6/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model6/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model6/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model6/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model6/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model6/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model6/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model6/checkpoints/weights.epoch_07.hdf5
#  87/183 [=============>................] - ETA: 0s - loss: 0.6196 - accuracy: 0.6523
# Epoch 7: saving model to ../models/model6/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model6/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model6/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model6/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model6/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model6/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model6/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model6/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model6/checkpoints/weights.epoch_07.hdf5
# 132/183 [====================>.........] - ETA: 0s - loss: 0.6240 - accuracy: 0.6487
# Epoch 7: saving model to ../models/model6/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model6/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model6/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model6/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model6/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model6/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model6/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model6/checkpoints/weights.epoch_07.hdf5
# 172/183 [===========================>..] - ETA: 0s - loss: 0.6229 - accuracy: 0.6493
# Epoch 7: saving model to ../models/model6/checkpoints/weights.epoch_07.hdf5
#
# Epoch 7: saving model to ../models/model6/checkpoints/weights.epoch_07.hdf5
# 183/183 [==============================] - 0s 1ms/step - loss: 0.6230 - accuracy: 0.6487
# Epoch 8/75
#   1/183 [..............................] - ETA: 0s - loss: 0.5995 - accuracy: 0.6875
# Epoch 8: saving model to ../models/model6/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model6/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model6/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model6/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model6/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model6/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model6/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model6/checkpoints/weights.epoch_08.hdf5
#  41/183 [=====>........................] - ETA: 0s - loss: 0.6190 - accuracy: 0.6562
# Epoch 8: saving model to ../models/model6/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model6/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model6/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model6/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model6/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model6/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model6/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model6/checkpoints/weights.epoch_08.hdf5
#  80/183 [============>.................] - ETA: 0s - loss: 0.6166 - accuracy: 0.6562
# Epoch 8: saving model to ../models/model6/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model6/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model6/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model6/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model6/checkpoints/weights.epoch_08.hdf5
# 104/183 [================>.............] - ETA: 0s - loss: 0.6180 - accuracy: 0.6547
# Epoch 8: saving model to ../models/model6/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model6/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model6/checkpoints/weights.epoch_08.hdf5
# 123/183 [===================>..........] - ETA: 0s - loss: 0.6161 - accuracy: 0.6550
# Epoch 8: saving model to ../models/model6/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model6/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model6/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model6/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model6/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model6/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model6/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model6/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model6/checkpoints/weights.epoch_08.hdf5
# 164/183 [=========================>....] - ETA: 0s - loss: 0.6233 - accuracy: 0.6448
# Epoch 8: saving model to ../models/model6/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model6/checkpoints/weights.epoch_08.hdf5
#
# Epoch 8: saving model to ../models/model6/checkpoints/weights.epoch_08.hdf5
# 183/183 [==============================] - 0s 2ms/step - loss: 0.6211 - accuracy: 0.6487
# Epoch 9/75
#
# Epoch 9: saving model to ../models/model6/checkpoints/weights.epoch_09.hdf5
#   1/183 [..............................] - ETA: 0s - loss: 0.7867 - accuracy: 0.3750
# Epoch 9: saving model to ../models/model6/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model6/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model6/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model6/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model6/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model6/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model6/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model6/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model6/checkpoints/weights.epoch_09.hdf5
#  46/183 [======>.......................] - ETA: 0s - loss: 0.6200 - accuracy: 0.6447
# Epoch 9: saving model to ../models/model6/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model6/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model6/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model6/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model6/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model6/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model6/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model6/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model6/checkpoints/weights.epoch_09.hdf5
#  91/183 [=============>................] - ETA: 0s - loss: 0.6160 - accuracy: 0.6525
# Epoch 9: saving model to ../models/model6/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model6/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model6/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model6/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model6/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model6/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model6/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model6/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model6/checkpoints/weights.epoch_09.hdf5
# 136/183 [=====================>........] - ETA: 0s - loss: 0.6193 - accuracy: 0.6505
# Epoch 9: saving model to ../models/model6/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model6/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model6/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model6/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model6/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model6/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model6/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model6/checkpoints/weights.epoch_09.hdf5
#
# Epoch 9: saving model to ../models/model6/checkpoints/weights.epoch_09.hdf5
# 183/183 [==============================] - 0s 1ms/step - loss: 0.6198 - accuracy: 0.6487
# Epoch 10/75
#   1/183 [..............................] - ETA: 0s - loss: 0.5613 - accuracy: 0.6562
# Epoch 10: saving model to ../models/model6/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model6/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model6/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model6/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model6/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model6/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model6/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model6/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model6/checkpoints/weights.epoch_10.hdf5
#  43/183 [======>.......................] - ETA: 0s - loss: 0.6187 - accuracy: 0.6432
# Epoch 10: saving model to ../models/model6/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model6/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model6/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model6/checkpoints/weights.epoch_10.hdf5
#  63/183 [=========>....................] - ETA: 0s - loss: 0.6143 - accuracy: 0.6483
# Epoch 10: saving model to ../models/model6/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model6/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model6/checkpoints/weights.epoch_10.hdf5
#  81/183 [============>.................] - ETA: 0s - loss: 0.6142 - accuracy: 0.6505
# Epoch 10: saving model to ../models/model6/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model6/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model6/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model6/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model6/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model6/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model6/checkpoints/weights.epoch_10.hdf5
# 113/183 [=================>............] - ETA: 0s - loss: 0.6173 - accuracy: 0.6488
# Epoch 10: saving model to ../models/model6/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model6/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model6/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model6/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model6/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model6/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model6/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model6/checkpoints/weights.epoch_10.hdf5
# 153/183 [========================>.....] - ETA: 0s - loss: 0.6225 - accuracy: 0.6430
# Epoch 10: saving model to ../models/model6/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model6/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model6/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model6/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model6/checkpoints/weights.epoch_10.hdf5
#
# Epoch 10: saving model to ../models/model6/checkpoints/weights.epoch_10.hdf5
# 183/183 [==============================] - 0s 2ms/step - loss: 0.6188 - accuracy: 0.6487
# Epoch 11/75
#   1/183 [..............................] - ETA: 0s - loss: 0.6348 - accuracy: 0.6250
# Epoch 11: saving model to ../models/model6/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model6/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model6/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model6/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model6/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model6/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model6/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model6/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model6/checkpoints/weights.epoch_11.hdf5
#  45/183 [======>.......................] - ETA: 0s - loss: 0.6260 - accuracy: 0.6472
# Epoch 11: saving model to ../models/model6/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model6/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model6/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model6/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model6/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model6/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model6/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model6/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model6/checkpoints/weights.epoch_11.hdf5
#  90/183 [=============>................] - ETA: 0s - loss: 0.6200 - accuracy: 0.6427
# Epoch 11: saving model to ../models/model6/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model6/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model6/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model6/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model6/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model6/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model6/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model6/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model6/checkpoints/weights.epoch_11.hdf5
# 135/183 [=====================>........] - ETA: 0s - loss: 0.6178 - accuracy: 0.6465
# Epoch 11: saving model to ../models/model6/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model6/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model6/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model6/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model6/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model6/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model6/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model6/checkpoints/weights.epoch_11.hdf5
#
# Epoch 11: saving model to ../models/model6/checkpoints/weights.epoch_11.hdf5
# 183/183 [==============================] - 0s 1ms/step - loss: 0.6175 - accuracy: 0.6496
# Epoch 12/75
#   1/183 [..............................] - ETA: 1s - loss: 0.5879 - accuracy: 0.7188
# Epoch 12: saving model to ../models/model6/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model6/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model6/checkpoints/weights.epoch_12.hdf5
#  12/183 [>.............................] - ETA: 0s - loss: 0.6022 - accuracy: 0.7005
# Epoch 12: saving model to ../models/model6/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model6/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model6/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model6/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model6/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model6/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model6/checkpoints/weights.epoch_12.hdf5
#  51/183 [=======>......................] - ETA: 0s - loss: 0.6098 - accuracy: 0.6777
# Epoch 12: saving model to ../models/model6/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model6/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model6/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model6/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model6/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model6/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model6/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model6/checkpoints/weights.epoch_12.hdf5
#  87/183 [=============>................] - ETA: 0s - loss: 0.6194 - accuracy: 0.6681
# Epoch 12: saving model to ../models/model6/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model6/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model6/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model6/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model6/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model6/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model6/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model6/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model6/checkpoints/weights.epoch_12.hdf5
# 132/183 [====================>.........] - ETA: 0s - loss: 0.6165 - accuracy: 0.6702
# Epoch 12: saving model to ../models/model6/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model6/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model6/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model6/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model6/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model6/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model6/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model6/checkpoints/weights.epoch_12.hdf5
#
# Epoch 12: saving model to ../models/model6/checkpoints/weights.epoch_12.hdf5
# 177/183 [============================>.] - ETA: 0s - loss: 0.6159 - accuracy: 0.6702
# Epoch 12: saving model to ../models/model6/checkpoints/weights.epoch_12.hdf5
# 183/183 [==============================] - 0s 2ms/step - loss: 0.6155 - accuracy: 0.6703
# Epoch 13/75
#   1/183 [..............................] - ETA: 0s - loss: 0.6658 - accuracy: 0.6875
# Epoch 13: saving model to ../models/model6/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model6/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model6/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model6/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model6/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model6/checkpoints/weights.epoch_13.hdf5
#  29/183 [===>..........................] - ETA: 0s - loss: 0.6191 - accuracy: 0.6433
# Epoch 13: saving model to ../models/model6/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model6/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model6/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model6/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model6/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model6/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model6/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model6/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model6/checkpoints/weights.epoch_13.hdf5
#  74/183 [===========>..................] - ETA: 0s - loss: 0.6149 - accuracy: 0.6651
# Epoch 13: saving model to ../models/model6/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model6/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model6/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model6/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model6/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model6/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model6/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model6/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model6/checkpoints/weights.epoch_13.hdf5
# 119/183 [==================>...........] - ETA: 0s - loss: 0.6170 - accuracy: 0.6699
# Epoch 13: saving model to ../models/model6/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model6/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model6/checkpoints/weights.epoch_13.hdf5
# 134/183 [====================>.........] - ETA: 0s - loss: 0.6173 - accuracy: 0.6698
# Epoch 13: saving model to ../models/model6/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model6/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model6/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model6/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model6/checkpoints/weights.epoch_13.hdf5
# 159/183 [=========================>....] - ETA: 0s - loss: 0.6161 - accuracy: 0.6708
# Epoch 13: saving model to ../models/model6/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model6/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model6/checkpoints/weights.epoch_13.hdf5
#
# Epoch 13: saving model to ../models/model6/checkpoints/weights.epoch_13.hdf5
# 183/183 [==============================] - 0s 2ms/step - loss: 0.6142 - accuracy: 0.6708
# Epoch 14/75
#
# Epoch 14: saving model to ../models/model6/checkpoints/weights.epoch_14.hdf5
#   1/183 [..............................] - ETA: 0s - loss: 0.6522 - accuracy: 0.6562
# Epoch 14: saving model to ../models/model6/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model6/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model6/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model6/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model6/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model6/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model6/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model6/checkpoints/weights.epoch_14.hdf5
#  42/183 [=====>........................] - ETA: 0s - loss: 0.6256 - accuracy: 0.6548
# Epoch 14: saving model to ../models/model6/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model6/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model6/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model6/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model6/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model6/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model6/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model6/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model6/checkpoints/weights.epoch_14.hdf5
#  86/183 [=============>................] - ETA: 0s - loss: 0.6197 - accuracy: 0.6599
# Epoch 14: saving model to ../models/model6/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model6/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model6/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model6/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model6/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model6/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model6/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model6/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model6/checkpoints/weights.epoch_14.hdf5
# 131/183 [====================>.........] - ETA: 0s - loss: 0.6126 - accuracy: 0.6722
# Epoch 14: saving model to ../models/model6/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model6/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model6/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model6/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model6/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model6/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model6/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model6/checkpoints/weights.epoch_14.hdf5
# 175/183 [===========================>..] - ETA: 0s - loss: 0.6148 - accuracy: 0.6687
# Epoch 14: saving model to ../models/model6/checkpoints/weights.epoch_14.hdf5
#
# Epoch 14: saving model to ../models/model6/checkpoints/weights.epoch_14.hdf5
# 183/183 [==============================] - 0s 1ms/step - loss: 0.6130 - accuracy: 0.6708
# Epoch 15/75
#   1/183 [..............................] - ETA: 0s - loss: 0.5703 - accuracy: 0.7188
# Epoch 15: saving model to ../models/model6/checkpoints/weights.epoch_15.hdf5
#
# Epoch 15: saving model to ../models/model6/checkpoints/weights.epoch_15.hdf5
#
# Epoch 15: saving model to ../models/model6/checkpoints/weights.epoch_15.hdf5
#
# Epoch 15: saving model to ../models/model6/checkpoints/weights.epoch_15.hdf5
#
# Epoch 15: saving model to ../models/model6/checkpoints/weights.epoch_15.hdf5
#  23/183 [==>...........................] - ETA: 0s - loss: 0.6205 - accuracy: 0.6576
# Epoch 15: saving model to ../models/model6/checkpoints/weights.epoch_15.hdf5
#
# Epoch 15: saving model to ../models/model6/checkpoints/weights.epoch_15.hdf5
#
# Epoch 15: saving model to ../models/model6/checkpoints/weights.epoch_15.hdf5
# ...
#
# Epoch 71: saving model to ../models/model6/checkpoints/weights.epoch_71.hdf5
#
# Epoch 71: saving model to ../models/model6/checkpoints/weights.epoch_71.hdf5
#
# Epoch 71: saving model to ../models/model6/checkpoints/weights.epoch_71.hdf5
# 120/183 [==================>...........] - ETA: 0s - loss: 0.5994 - accuracy: 0.6922
# Epoch 71: saving model to ../models/model6/checkpoints/weights.epoch_71.hdf5
#
# Epoch 71: saving model to ../models/model6/checkpoints/weights.epoch_71.hdf5
#
# Epoch 71: saving model to ../models/model6/checkpoints/weights.epoch_71.hdf5
# 135/183 [=====================>........] - ETA: 0s - loss: 0.5968 - accuracy: 0.6931
# Epoch 71: saving model to ../models/model6/checkpoints/weights.epoch_71.hdf5
#
# Epoch 71: saving model to ../models/model6/checkpoints/weights.epoch_71.hdf5
#
# Epoch 71: saving model to ../models/model6/checkpoints/weights.epoch_71.hdf5
#
# Epoch 71: saving model to ../models/model6/checkpoints/weights.epoch_71.hdf5
#
# Epoch 71: saving model to ../models/model6/checkpoints/weights.epoch_71.hdf5
#
# Epoch 71: saving model to ../models/model6/checkpoints/weights.epoch_71.hdf5
# 165/183 [==========================>...] - ETA: 0s - loss: 0.5995 - accuracy: 0.6881
# Epoch 71: saving model to ../models/model6/checkpoints/weights.epoch_71.hdf5
#
# Epoch 71: saving model to ../models/model6/checkpoints/weights.epoch_71.hdf5
#
# Epoch 71: saving model to ../models/model6/checkpoints/weights.epoch_71.hdf5
# 183/183 [==============================] - 0s 2ms/step - loss: 0.5974 - accuracy: 0.6911
# Epoch 72/75
#   1/183 [..............................] - ETA: 0s - loss: 0.4735 - accuracy: 0.7812
# Epoch 72: saving model to ../models/model6/checkpoints/weights.epoch_72.hdf5
#
# Epoch 72: saving model to ../models/model6/checkpoints/weights.epoch_72.hdf5
#
# Epoch 72: saving model to ../models/model6/checkpoints/weights.epoch_72.hdf5
#
# Epoch 72: saving model to ../models/model6/checkpoints/weights.epoch_72.hdf5
#
# Epoch 72: saving model to ../models/model6/checkpoints/weights.epoch_72.hdf5
#
# Epoch 72: saving model to ../models/model6/checkpoints/weights.epoch_72.hdf5
#
# Epoch 72: saving model to ../models/model6/checkpoints/weights.epoch_72.hdf5
#  32/183 [====>.........................] - ETA: 0s - loss: 0.6130 - accuracy: 0.6719
# Epoch 72: saving model to ../models/model6/checkpoints/weights.epoch_72.hdf5
#  38/183 [=====>........................] - ETA: 0s - loss: 0.6095 - accuracy: 0.6719
# Epoch 72: saving model to ../models/model6/checkpoints/weights.epoch_72.hdf5
#  42/183 [=====>........................] - ETA: 0s - loss: 0.6092 - accuracy: 0.6756
# Epoch 72: saving model to ../models/model6/checkpoints/weights.epoch_72.hdf5
#
# Epoch 72: saving model to ../models/model6/checkpoints/weights.epoch_72.hdf5
#
# Epoch 72: saving model to ../models/model6/checkpoints/weights.epoch_72.hdf5
#
# Epoch 72: saving model to ../models/model6/checkpoints/weights.epoch_72.hdf5
#
# Epoch 72: saving model to ../models/model6/checkpoints/weights.epoch_72.hdf5
#
# Epoch 72: saving model to ../models/model6/checkpoints/weights.epoch_72.hdf5
#  72/183 [==========>...................] - ETA: 0s - loss: 0.5985 - accuracy: 0.6918
# Epoch 72: saving model to ../models/model6/checkpoints/weights.epoch_72.hdf5
#
# Epoch 72: saving model to ../models/model6/checkpoints/weights.epoch_72.hdf5
#
# Epoch 72: saving model to ../models/model6/checkpoints/weights.epoch_72.hdf5
#
# Epoch 72: saving model to ../models/model6/checkpoints/weights.epoch_72.hdf5
#
# Epoch 72: saving model to ../models/model6/checkpoints/weights.epoch_72.hdf5
#  98/183 [===============>..............] - ETA: 0s - loss: 0.6038 - accuracy: 0.6888
# Epoch 72: saving model to ../models/model6/checkpoints/weights.epoch_72.hdf5
#
# Epoch 72: saving model to ../models/model6/checkpoints/weights.epoch_72.hdf5
#
# Epoch 72: saving model to ../models/model6/checkpoints/weights.epoch_72.hdf5
#
# Epoch 72: saving model to ../models/model6/checkpoints/weights.epoch_72.hdf5
#
# Epoch 72: saving model to ../models/model6/checkpoints/weights.epoch_72.hdf5
#
# Epoch 72: saving model to ../models/model6/checkpoints/weights.epoch_72.hdf5
#
# Epoch 72: saving model to ../models/model6/checkpoints/weights.epoch_72.hdf5
#
# Epoch 72: saving model to ../models/model6/checkpoints/weights.epoch_72.hdf5
#
# Epoch 72: saving model to ../models/model6/checkpoints/weights.epoch_72.hdf5
# 142/183 [======================>.......] - ETA: 0s - loss: 0.6005 - accuracy: 0.6873
# Epoch 72: saving model to ../models/model6/checkpoints/weights.epoch_72.hdf5
#
# Epoch 72: saving model to ../models/model6/checkpoints/weights.epoch_72.hdf5
#
# Epoch 72: saving model to ../models/model6/checkpoints/weights.epoch_72.hdf5
#
# Epoch 72: saving model to ../models/model6/checkpoints/weights.epoch_72.hdf5
#
# Epoch 72: saving model to ../models/model6/checkpoints/weights.epoch_72.hdf5
# 171/183 [===========================>..] - ETA: 0s - loss: 0.5962 - accuracy: 0.6908
# Epoch 72: saving model to ../models/model6/checkpoints/weights.epoch_72.hdf5
# 172/183 [===========================>..] - ETA: 0s - loss: 0.5962 - accuracy: 0.6911
# Epoch 72: saving model to ../models/model6/checkpoints/weights.epoch_72.hdf5
#
# Epoch 72: saving model to ../models/model6/checkpoints/weights.epoch_72.hdf5
# 183/183 [==============================] - 0s 2ms/step - loss: 0.5978 - accuracy: 0.6902
# Epoch 73/75
#   1/183 [..............................] - ETA: 0s - loss: 0.5733 - accuracy: 0.7500
# Epoch 73: saving model to ../models/model6/checkpoints/weights.epoch_73.hdf5
#
# Epoch 73: saving model to ../models/model6/checkpoints/weights.epoch_73.hdf5
#
# Epoch 73: saving model to ../models/model6/checkpoints/weights.epoch_73.hdf5
#
# Epoch 73: saving model to ../models/model6/checkpoints/weights.epoch_73.hdf5
#
# Epoch 73: saving model to ../models/model6/checkpoints/weights.epoch_73.hdf5
#
# Epoch 73: saving model to ../models/model6/checkpoints/weights.epoch_73.hdf5
#  30/183 [===>..........................] - ETA: 0s - loss: 0.5836 - accuracy: 0.7042
# Epoch 73: saving model to ../models/model6/checkpoints/weights.epoch_73.hdf5
#
# Epoch 73: saving model to ../models/model6/checkpoints/weights.epoch_73.hdf5
#
# Epoch 73: saving model to ../models/model6/checkpoints/weights.epoch_73.hdf5
#
# Epoch 73: saving model to ../models/model6/checkpoints/weights.epoch_73.hdf5
#
# Epoch 73: saving model to ../models/model6/checkpoints/weights.epoch_73.hdf5
#
# Epoch 73: saving model to ../models/model6/checkpoints/weights.epoch_73.hdf5
#  59/183 [========>.....................] - ETA: 0s - loss: 0.5939 - accuracy: 0.7007
# Epoch 73: saving model to ../models/model6/checkpoints/weights.epoch_73.hdf5
#
# Epoch 73: saving model to ../models/model6/checkpoints/weights.epoch_73.hdf5
#
# Epoch 73: saving model to ../models/model6/checkpoints/weights.epoch_73.hdf5
#
# Epoch 73: saving model to ../models/model6/checkpoints/weights.epoch_73.hdf5
#
# Epoch 73: saving model to ../models/model6/checkpoints/weights.epoch_73.hdf5
#
# Epoch 73: saving model to ../models/model6/checkpoints/weights.epoch_73.hdf5
#
# Epoch 73: saving model to ../models/model6/checkpoints/weights.epoch_73.hdf5
#
# Epoch 73: saving model to ../models/model6/checkpoints/weights.epoch_73.hdf5
# 100/183 [===============>..............] - ETA: 0s - loss: 0.5946 - accuracy: 0.6947
# Epoch 73: saving model to ../models/model6/checkpoints/weights.epoch_73.hdf5
#
# Epoch 73: saving model to ../models/model6/checkpoints/weights.epoch_73.hdf5
#
# Epoch 73: saving model to ../models/model6/checkpoints/weights.epoch_73.hdf5
#
# Epoch 73: saving model to ../models/model6/checkpoints/weights.epoch_73.hdf5
#
# Epoch 73: saving model to ../models/model6/checkpoints/weights.epoch_73.hdf5
# 124/183 [===================>..........] - ETA: 0s - loss: 0.5939 - accuracy: 0.6941
# Epoch 73: saving model to ../models/model6/checkpoints/weights.epoch_73.hdf5
#
# Epoch 73: saving model to ../models/model6/checkpoints/weights.epoch_73.hdf5
#
# Epoch 73: saving model to ../models/model6/checkpoints/weights.epoch_73.hdf5
#
# Epoch 73: saving model to ../models/model6/checkpoints/weights.epoch_73.hdf5
# 144/183 [======================>.......] - ETA: 0s - loss: 0.5968 - accuracy: 0.6899
# Epoch 73: saving model to ../models/model6/checkpoints/weights.epoch_73.hdf5
#
# Epoch 73: saving model to ../models/model6/checkpoints/weights.epoch_73.hdf5
#
# Epoch 73: saving model to ../models/model6/checkpoints/weights.epoch_73.hdf5
# 161/183 [=========================>....] - ETA: 0s - loss: 0.5954 - accuracy: 0.6912
# Epoch 73: saving model to ../models/model6/checkpoints/weights.epoch_73.hdf5
#
# Epoch 73: saving model to ../models/model6/checkpoints/weights.epoch_73.hdf5
#
# Epoch 73: saving model to ../models/model6/checkpoints/weights.epoch_73.hdf5
#
# Epoch 73: saving model to ../models/model6/checkpoints/weights.epoch_73.hdf5
# 183/183 [==============================] - 0s 2ms/step - loss: 0.5973 - accuracy: 0.6908
# Epoch 74/75
#
# Epoch 74: saving model to ../models/model6/checkpoints/weights.epoch_74.hdf5
#   1/183 [..............................] - ETA: 0s - loss: 0.5525 - accuracy: 0.6562
# Epoch 74: saving model to ../models/model6/checkpoints/weights.epoch_74.hdf5
#
# Epoch 74: saving model to ../models/model6/checkpoints/weights.epoch_74.hdf5
#
# Epoch 74: saving model to ../models/model6/checkpoints/weights.epoch_74.hdf5
#
# Epoch 74: saving model to ../models/model6/checkpoints/weights.epoch_74.hdf5
#
# Epoch 74: saving model to ../models/model6/checkpoints/weights.epoch_74.hdf5
#
# Epoch 74: saving model to ../models/model6/checkpoints/weights.epoch_74.hdf5
#
# Epoch 74: saving model to ../models/model6/checkpoints/weights.epoch_74.hdf5
#
# Epoch 74: saving model to ../models/model6/checkpoints/weights.epoch_74.hdf5
#  41/183 [=====>........................] - ETA: 0s - loss: 0.6024 - accuracy: 0.6845
# Epoch 74: saving model to ../models/model6/checkpoints/weights.epoch_74.hdf5
#
# Epoch 74: saving model to ../models/model6/checkpoints/weights.epoch_74.hdf5
#
# Epoch 74: saving model to ../models/model6/checkpoints/weights.epoch_74.hdf5
#
# Epoch 74: saving model to ../models/model6/checkpoints/weights.epoch_74.hdf5
#  61/183 [=========>....................] - ETA: 0s - loss: 0.6014 - accuracy: 0.6921
# Epoch 74: saving model to ../models/model6/checkpoints/weights.epoch_74.hdf5
#
# Epoch 74: saving model to ../models/model6/checkpoints/weights.epoch_74.hdf5
#  71/183 [==========>...................] - ETA: 0s - loss: 0.6034 - accuracy: 0.6888
# Epoch 74: saving model to ../models/model6/checkpoints/weights.epoch_74.hdf5
#
# Epoch 74: saving model to ../models/model6/checkpoints/weights.epoch_74.hdf5
#
# Epoch 74: saving model to ../models/model6/checkpoints/weights.epoch_74.hdf5
#  87/183 [=============>................] - ETA: 0s - loss: 0.6035 - accuracy: 0.6875
# Epoch 74: saving model to ../models/model6/checkpoints/weights.epoch_74.hdf5
#
# Epoch 74: saving model to ../models/model6/checkpoints/weights.epoch_74.hdf5
#
# Epoch 74: saving model to ../models/model6/checkpoints/weights.epoch_74.hdf5
#
# Epoch 74: saving model to ../models/model6/checkpoints/weights.epoch_74.hdf5
#
# Epoch 74: saving model to ../models/model6/checkpoints/weights.epoch_74.hdf5
# 111/183 [=================>............] - ETA: 0s - loss: 0.6062 - accuracy: 0.6864
# Epoch 74: saving model to ../models/model6/checkpoints/weights.epoch_74.hdf5
#
# Epoch 74: saving model to ../models/model6/checkpoints/weights.epoch_74.hdf5
#
# Epoch 74: saving model to ../models/model6/checkpoints/weights.epoch_74.hdf5
#
# Epoch 74: saving model to ../models/model6/checkpoints/weights.epoch_74.hdf5
#
# Epoch 74: saving model to ../models/model6/checkpoints/weights.epoch_74.hdf5
#
# Epoch 74: saving model to ../models/model6/checkpoints/weights.epoch_74.hdf5
#
# Epoch 74: saving model to ../models/model6/checkpoints/weights.epoch_74.hdf5
#
# Epoch 74: saving model to ../models/model6/checkpoints/weights.epoch_74.hdf5
#
# Epoch 74: saving model to ../models/model6/checkpoints/weights.epoch_74.hdf5
# 156/183 [========================>.....] - ETA: 0s - loss: 0.5982 - accuracy: 0.6909
# Epoch 74: saving model to ../models/model6/checkpoints/weights.epoch_74.hdf5
#
# Epoch 74: saving model to ../models/model6/checkpoints/weights.epoch_74.hdf5
#
# Epoch 74: saving model to ../models/model6/checkpoints/weights.epoch_74.hdf5
#
# Epoch 74: saving model to ../models/model6/checkpoints/weights.epoch_74.hdf5
#
# Epoch 74: saving model to ../models/model6/checkpoints/weights.epoch_74.hdf5
# 183/183 [==============================] - 0s 2ms/step - loss: 0.5971 - accuracy: 0.6921
# Epoch 75/75
#   1/183 [..............................] - ETA: 0s - loss: 0.6731 - accuracy: 0.6250
# Epoch 75: saving model to ../models/model6/checkpoints/weights.epoch_75.hdf5
#
# Epoch 75: saving model to ../models/model6/checkpoints/weights.epoch_75.hdf5
#
# Epoch 75: saving model to ../models/model6/checkpoints/weights.epoch_75.hdf5
#
# Epoch 75: saving model to ../models/model6/checkpoints/weights.epoch_75.hdf5
#
# Epoch 75: saving model to ../models/model6/checkpoints/weights.epoch_75.hdf5
#
# Epoch 75: saving model to ../models/model6/checkpoints/weights.epoch_75.hdf5
#  28/183 [===>..........................] - ETA: 0s - loss: 0.5942 - accuracy: 0.6987
# Epoch 75: saving model to ../models/model6/checkpoints/weights.epoch_75.hdf5
#
# Epoch 75: saving model to ../models/model6/checkpoints/weights.epoch_75.hdf5
#  38/183 [=====>........................] - ETA: 0s - loss: 0.5974 - accuracy: 0.6908
# Epoch 75: saving model to ../models/model6/checkpoints/weights.epoch_75.hdf5
#
# Epoch 75: saving model to ../models/model6/checkpoints/weights.epoch_75.hdf5
#
# Epoch 75: saving model to ../models/model6/checkpoints/weights.epoch_75.hdf5
#
# Epoch 75: saving model to ../models/model6/checkpoints/weights.epoch_75.hdf5
#
# Epoch 75: saving model to ../models/model6/checkpoints/weights.epoch_75.hdf5
#  66/183 [=========>....................] - ETA: 0s - loss: 0.5957 - accuracy: 0.6951
# Epoch 75: saving model to ../models/model6/checkpoints/weights.epoch_75.hdf5
#
# Epoch 75: saving model to ../models/model6/checkpoints/weights.epoch_75.hdf5
#
# Epoch 75: saving model to ../models/model6/checkpoints/weights.epoch_75.hdf5
#
# Epoch 75: saving model to ../models/model6/checkpoints/weights.epoch_75.hdf5
#
# Epoch 75: saving model to ../models/model6/checkpoints/weights.epoch_75.hdf5
#
# Epoch 75: saving model to ../models/model6/checkpoints/weights.epoch_75.hdf5
#
# Epoch 75: saving model to ../models/model6/checkpoints/weights.epoch_75.hdf5
#
# Epoch 75: saving model to ../models/model6/checkpoints/weights.epoch_75.hdf5
# 103/183 [===============>..............] - ETA: 0s - loss: 0.5964 - accuracy: 0.6893
# Epoch 75: saving model to ../models/model6/checkpoints/weights.epoch_75.hdf5
#
# Epoch 75: saving model to ../models/model6/checkpoints/weights.epoch_75.hdf5
#
# Epoch 75: saving model to ../models/model6/checkpoints/weights.epoch_75.hdf5
#
# Epoch 75: saving model to ../models/model6/checkpoints/weights.epoch_75.hdf5
#
# Epoch 75: saving model to ../models/model6/checkpoints/weights.epoch_75.hdf5
#
# Epoch 75: saving model to ../models/model6/checkpoints/weights.epoch_75.hdf5
#
# Epoch 75: saving model to ../models/model6/checkpoints/weights.epoch_75.hdf5
# 138/183 [=====================>........] - ETA: 0s - loss: 0.5930 - accuracy: 0.6963
# Epoch 75: saving model to ../models/model6/checkpoints/weights.epoch_75.hdf5
#
# Epoch 75: saving model to ../models/model6/checkpoints/weights.epoch_75.hdf5
#
# Epoch 75: saving model to ../models/model6/checkpoints/weights.epoch_75.hdf5
#
# Epoch 75: saving model to ../models/model6/checkpoints/weights.epoch_75.hdf5
#
# Epoch 75: saving model to ../models/model6/checkpoints/weights.epoch_75.hdf5
#
# Epoch 75: saving model to ../models/model6/checkpoints/weights.epoch_75.hdf5
# 170/183 [==========================>...] - ETA: 0s - loss: 0.5957 - accuracy: 0.6912
# Epoch 75: saving model to ../models/model6/checkpoints/weights.epoch_75.hdf5
# 173/183 [===========================>..] - ETA: 0s - loss: 0.5959 - accuracy: 0.6913
# Epoch 75: saving model to ../models/model6/checkpoints/weights.epoch_75.hdf5
#
# Epoch 75: saving model to ../models/model6/checkpoints/weights.epoch_75.hdf5
# 183/183 [==============================] - 0s 2ms/step - loss: 0.5971 - accuracy: 0.6914

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 61/61 - 0s - loss: 0.5882 - accuracy: 0.6993 - 95ms/epoch - 2ms/step
# Loss: 0.5881734490394592, Accuracy: 0.6992827653884888

# %%
# Export our model to HDF5 file
nn.save('../models/model6/model.h5')
