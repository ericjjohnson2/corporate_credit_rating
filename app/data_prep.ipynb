# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint
import pandas as pd
import sqlite3

# %%
connection = sqlite3.connect('../data/db.sqlite')

# Import DB into pandas dataframe
df = pd.read_sql_query("SELECT * FROM ratings", connection)

connection.close()

df.head()
# Out:
#                         Rating Agency                     Corporation Rating  \
# 0  Standard & Poor's Ratings Services       American States Water Co.     A-
# 1  Standard & Poor's Ratings Services  Automatic Data Processing Inc.    AAA
# 2  Standard & Poor's Ratings Services                      Avnet Inc.   BBB-
# 3  Standard & Poor's Ratings Services    California Water Service Co.    AA-
# 4  Standard & Poor's Ratings Services            Cardinal Health Inc.      A
#
#   Rating Date      CIK  Binary Rating  SIC Code Sector Ticker  Current Ratio  \
# 0  2010-07-30  1056903              1    4941.0  Utils    AWR         1.1507
# 1  2010-09-16     8670              1    7374.0  BusEq    ADP         1.1129
# 2  2010-11-23     8858              1    5065.0  Shops    AVT         1.9276
# 3  2010-06-29  1035201              1    4941.0  Utils    CWT         0.8358
# 4  2010-07-14   721371              1    5122.0  Shops    CAH         1.2931
#
#    ...  EBITDA Margin  Pre-Tax Profit Margin  Net Profit Margin  \
# 0  ...        28.9834                13.6093             8.3224
# 1  ...        23.9379                20.8699            13.5690
# 2  ...         3.6338                 3.0536             2.1418
# 3  ...        27.9377                15.1135             9.0246
# 4  ...         1.5847                 1.2304             0.6518
#
#    Asset Turnover  ROE - Return On Equity  Return On Tangible Equity  \
# 0          0.3173                  8.1724                     8.1978
# 1          0.3324                 22.0354                    47.2858
# 2          2.4620                 13.6376                    16.7991
# 3          0.2946                  9.6412                     9.7015
# 4          4.9276                 11.1256                    19.4184
#
#    ROA - Return On Assets  ROI - Return On Investment  \
# 0                  2.6385                      4.4530
# 1                  4.4944                     21.8765
# 2                  5.2731                      9.6494
# 3                  2.6583                      5.1018
# 4                  2.9364                      8.1844
#
#    Operating Cash Flow Per Share  Free Cash Flow Per Share
# 0                         1.9957                   -0.1333
# 1                         0.2501                    0.3132
# 2                        -7.6079                   -7.3231
# 3                         1.7438                   -0.8999
# 4                         1.9725                    2.4174
#
# [5 rows x 25 columns]

# %%
# Drop columns that won't be needed for the model
# More columns may be dropped later
reduced_df = df.drop(columns=['Corporation', 'CIK', 'Ticker'])
reduced_df.head()
# Out:
#                         Rating Agency Rating Rating Date  Binary Rating  \
# 0  Standard & Poor's Ratings Services     A-  2010-07-30              1
# 1  Standard & Poor's Ratings Services    AAA  2010-09-16              1
# 2  Standard & Poor's Ratings Services   BBB-  2010-11-23              1
# 3  Standard & Poor's Ratings Services    AA-  2010-06-29              1
# 4  Standard & Poor's Ratings Services      A  2010-07-14              1
#
#    SIC Code Sector  Current Ratio  Long-term Debt / Capital  \
# 0    4941.0  Utils         1.1507                    0.4551
# 1    7374.0  BusEq         1.1129                    0.0072
# 2    5065.0  Shops         1.9276                    0.2924
# 3    4941.0  Utils         0.8358                    0.4708
# 4    5122.0  Shops         1.2931                    0.2644
#
#    Debt/Equity Ratio  Gross Margin  ...  EBITDA Margin  Pre-Tax Profit Margin  \
# 0             0.8847       77.6230  ...        28.9834                13.6093
# 1             0.0073       43.6619  ...        23.9379                20.8699
# 2             0.4255       11.9008  ...         3.6338                 3.0536
# 3             0.9491       64.5096  ...        27.9377                15.1135
# 4             0.4036        3.8385  ...         1.5847                 1.2304
#
#    Net Profit Margin  Asset Turnover  ROE - Return On Equity  \
# 0             8.3224          0.3173                  8.1724
# 1            13.5690          0.3324                 22.0354
# 2             2.1418          2.4620                 13.6376
# 3             9.0246          0.2946                  9.6412
# 4             0.6518          4.9276                 11.1256
#
#    Return On Tangible Equity  ROA - Return On Assets  \
# 0                     8.1978                  2.6385
# 1                    47.2858                  4.4944
# 2                    16.7991                  5.2731
# 3                     9.7015                  2.6583
# 4                    19.4184                  2.9364
#
#    ROI - Return On Investment  Operating Cash Flow Per Share  \
# 0                      4.4530                         1.9957
# 1                     21.8765                         0.2501
# 2                      9.6494                        -7.6079
# 3                      5.1018                         1.7438
# 4                      8.1844                         1.9725
#
#    Free Cash Flow Per Share
# 0                   -0.1333
# 1                    0.3132
# 2                   -7.3231
# 3                   -0.8999
# 4                    2.4174
#
# [5 rows x 22 columns]

# %%
# Used code from https://stackoverflow.com/questions/14247586/how-to-select-rows-with-one-or-more-nulls-from-a-pandas-dataframe-without-listin
# Look for nulls
def nans(df): return df[df.isnull().any(axis=1)]
nans(reduced_df)
# Out:
# Empty DataFrame
# Columns: [Rating Agency, Rating, Rating Date, Binary Rating, SIC Code, Sector, Current Ratio, Long-term Debt / Capital, Debt/Equity Ratio, Gross Margin, Operating Margin, EBIT Margin, EBITDA Margin, Pre-Tax Profit Margin, Net Profit Margin, Asset Turnover, ROE - Return On Equity, Return On Tangible Equity, ROA - Return On Assets, ROI - Return On Investment, Operating Cash Flow Per Share, Free Cash Flow Per Share]
# Index: []
#
# [0 rows x 22 columns]

# %%
# Checking for NA's
def nans2(df): return df[df.isna().any(axis=1)]
nans2(reduced_df)
# Out:
# Empty DataFrame
# Columns: [Rating Agency, Rating, Rating Date, Binary Rating, SIC Code, Sector, Current Ratio, Long-term Debt / Capital, Debt/Equity Ratio, Gross Margin, Operating Margin, EBIT Margin, EBITDA Margin, Pre-Tax Profit Margin, Net Profit Margin, Asset Turnover, ROE - Return On Equity, Return On Tangible Equity, ROA - Return On Assets, ROI - Return On Investment, Operating Cash Flow Per Share, Free Cash Flow Per Share]
# Index: []
#
# [0 rows x 22 columns]

# %%
# Checking
reduced_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7805 entries, 0 to 7804
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Rating Agency                  7805 non-null   object
#  1   Rating                         7805 non-null   object
#  2   Rating Date                    7805 non-null   object
#  3   Binary Rating                  7805 non-null   int64
#  4   SIC Code                       7805 non-null   float64
#  5   Sector                         7805 non-null   object
#  6   Current Ratio                  7805 non-null   float64
#  7   Long-term Debt / Capital       7805 non-null   float64
#  8   Debt/Equity Ratio              7805 non-null   float64
#  9   Gross Margin                   7805 non-null   float64
#  10  Operating Margin               7805 non-null   float64
#  11  EBIT Margin                    7805 non-null   float64
#  12  EBITDA Margin                  7805 non-null   float64
#  13  Pre-Tax Profit Margin          7805 non-null   float64
#  14  Net Profit Margin              7805 non-null   float64
#  15  Asset Turnover                 7805 non-null   float64
#  16  ROE - Return On Equity         7805 non-null   float64
#  17  Return On Tangible Equity      7805 non-null   float64
#  18  ROA - Return On Assets         7805 non-null   float64
#  19  ROI - Return On Investment     7805 non-null   float64
#  20  Operating Cash Flow Per Share  7805 non-null   float64
#  21  Free Cash Flow Per Share       7805 non-null   float64
# dtypes: float64(17), int64(1), object(4)
# memory usage: 1.3+ MB

# %%
# Using Rating might be a form of over fitting but trying to see if there's a way to bin it
# What are the distribution of Ratings?
reduced_df['Rating'].value_counts()
# Out:
# Rating
# BBB     910
# BBB+    846
# A       836
# A-      722
# BBB-    705
# BB+     545
# A+      478
# BB      453
# BB-     427
# B+      422
# B       310
# B-      288
# AA-     254
# AA      185
# CCC+    151
# AAA      90
# AA+      73
# CCC      65
# CC       18
# C        11
# CCC-     10
# D         5
# CC+       1
# Name: count, dtype: int64

# %%
# Dictionary mapping ratings to numbers
rating_mapping = {'AAA': 1, 'AA+': 1, 'AA': 2, 'AA-': 2, 'A+': 3, 'A': 3, 'A-': 4, 'BBB+': 5, 'BBB': 6, 'BBB-': 7, 'BB+': 8, 'BB': 8, 'BB-': 9, 'B+': 8, 'B': 10, 'B-': 10, \
                  'C': 11, 'CCC': 11, 'CC': 11, 'CC+': 11, 'CCC-': 11, 'CCC+': 11, 'D': 12}

# Replace ratings with numbers in reduced_df
reduced_df['Rating'] = reduced_df['Rating'].replace(rating_mapping)

# Double Check
reduced_df['Rating'].value_counts()
# Out:
# Rating
# 8     1420
# 3     1314
# 6      910
# 5      846
# 4      722
# 7      705
# 10     598
# 2      439
# 9      427
# 11     256
# 1      163
# 12       5
# Name: count, dtype: int64

# %%
reduced_df['Rating'].head()
# Out:
# 0    4
# 1    1
# 2    7
# 3    2
# 4    3
# Name: Rating, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
reduced_numeric = pd.get_dummies(reduced_df)

# %%
reduced_numeric.head()
# Out:
#    Rating  Binary Rating  SIC Code  Current Ratio  Long-term Debt / Capital  \
# 0       4              1    4941.0         1.1507                    0.4551
# 1       1              1    7374.0         1.1129                    0.0072
# 2       7              1    5065.0         1.9276                    0.2924
# 3       2              1    4941.0         0.8358                    0.4708
# 4       3              1    5122.0         1.2931                    0.2644
#
#    Debt/Equity Ratio  Gross Margin  Operating Margin  EBIT Margin  \
# 0             0.8847       77.6230           19.4839      19.4839
# 1             0.0073       43.6619           19.8327      19.8327
# 2             0.4255       11.9008            3.3173       3.3173
# 3             0.9491       64.5096           18.4549      18.4549
# 4             0.4036        3.8385            1.3269       1.3269
#
#    EBITDA Margin  ...  Sector_Durbl  Sector_Enrgy  Sector_Hlth  Sector_Manuf  \
# 0        28.9834  ...         False         False        False         False
# 1        23.9379  ...         False         False        False         False
# 2         3.6338  ...         False         False        False         False
# 3        27.9377  ...         False         False        False         False
# 4         1.5847  ...         False         False        False         False
#
#    Sector_Money  Sector_NoDur  Sector_Other  Sector_Shops  Sector_Telcm  \
# 0         False         False         False         False         False
# 1         False         False         False         False         False
# 2         False         False         False          True         False
# 3         False         False         False         False         False
# 4         False         False         False          True         False
#
#    Sector_Utils
# 0          True
# 1         False
# 2         False
# 3          True
# 4         False
#
# [5 rows x 1452 columns]
