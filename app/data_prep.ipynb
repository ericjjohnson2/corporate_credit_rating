# %%
# Import the required libraries and dependencies
import pandas as pd
import hvplot.pandas
from pathlib import Path
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint
import sqlite3
import hvplot.pandas
import numpy as np
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# WARNING:tensorflow:From c:\Users\woini\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
connection = sqlite3.connect('../data/db.sqlite')

# Import DB into pandas dataframe
df = pd.read_sql_query("SELECT * FROM ratings", connection)

connection.close()

df.head()
# Out:
#                         Rating Agency                     Corporation Rating  \
# 0  Standard & Poor's Ratings Services       American States Water Co.     A-
# 1  Standard & Poor's Ratings Services  Automatic Data Processing Inc.    AAA
# 2  Standard & Poor's Ratings Services                      Avnet Inc.   BBB-
# 3  Standard & Poor's Ratings Services    California Water Service Co.    AA-
# 4  Standard & Poor's Ratings Services            Cardinal Health Inc.      A
#
#   Rating Date      CIK  Binary Rating  SIC Code Sector Ticker  Current Ratio  \
# 0  2010-07-30  1056903              1    4941.0  Utils    AWR         1.1507
# 1  2010-09-16     8670              1    7374.0  BusEq    ADP         1.1129
# 2  2010-11-23     8858              1    5065.0  Shops    AVT         1.9276
# 3  2010-06-29  1035201              1    4941.0  Utils    CWT         0.8358
# 4  2010-07-14   721371              1    5122.0  Shops    CAH         1.2931
#
#    ...  EBITDA Margin  Pre-Tax Profit Margin  Net Profit Margin  \
# 0  ...        28.9834                13.6093             8.3224
# 1  ...        23.9379                20.8699            13.5690
# 2  ...         3.6338                 3.0536             2.1418
# 3  ...        27.9377                15.1135             9.0246
# 4  ...         1.5847                 1.2304             0.6518
#
#    Asset Turnover  ROE - Return On Equity  Return On Tangible Equity  \
# 0          0.3173                  8.1724                     8.1978
# 1          0.3324                 22.0354                    47.2858
# 2          2.4620                 13.6376                    16.7991
# 3          0.2946                  9.6412                     9.7015
# 4          4.9276                 11.1256                    19.4184
#
#    ROA - Return On Assets  ROI - Return On Investment  \
# 0                  2.6385                      4.4530
# 1                  4.4944                     21.8765
# 2                  5.2731                      9.6494
# 3                  2.6583                      5.1018
# 4                  2.9364                      8.1844
#
#    Operating Cash Flow Per Share  Free Cash Flow Per Share
# 0                         1.9957                   -0.1333
# 1                         0.2501                    0.3132
# 2                        -7.6079                   -7.3231
# 3                         1.7438                   -0.8999
# 4                         1.9725                    2.4174
#
# [5 rows x 25 columns]

# %%
reduced_df = df.drop(columns=['CIK', 'Ticker', 'Rating Date', 'SIC Code'])
reduced_df.head()
# Out:
#                         Rating Agency                     Corporation Rating  \
# 0  Standard & Poor's Ratings Services       American States Water Co.     A-
# 1  Standard & Poor's Ratings Services  Automatic Data Processing Inc.    AAA
# 2  Standard & Poor's Ratings Services                      Avnet Inc.   BBB-
# 3  Standard & Poor's Ratings Services    California Water Service Co.    AA-
# 4  Standard & Poor's Ratings Services            Cardinal Health Inc.      A
#
#    Binary Rating Sector  Current Ratio  Long-term Debt / Capital  \
# 0              1  Utils         1.1507                    0.4551
# 1              1  BusEq         1.1129                    0.0072
# 2              1  Shops         1.9276                    0.2924
# 3              1  Utils         0.8358                    0.4708
# 4              1  Shops         1.2931                    0.2644
#
#    Debt/Equity Ratio  Gross Margin  Operating Margin  ...  EBITDA Margin  \
# 0             0.8847       77.6230           19.4839  ...        28.9834
# 1             0.0073       43.6619           19.8327  ...        23.9379
# 2             0.4255       11.9008            3.3173  ...         3.6338
# 3             0.9491       64.5096           18.4549  ...        27.9377
# 4             0.4036        3.8385            1.3269  ...         1.5847
#
#    Pre-Tax Profit Margin  Net Profit Margin  Asset Turnover  \
# 0                13.6093             8.3224          0.3173
# 1                20.8699            13.5690          0.3324
# 2                 3.0536             2.1418          2.4620
# 3                15.1135             9.0246          0.2946
# 4                 1.2304             0.6518          4.9276
#
#    ROE - Return On Equity  Return On Tangible Equity  ROA - Return On Assets  \
# 0                  8.1724                     8.1978                  2.6385
# 1                 22.0354                    47.2858                  4.4944
# 2                 13.6376                    16.7991                  5.2731
# 3                  9.6412                     9.7015                  2.6583
# 4                 11.1256                    19.4184                  2.9364
#
#    ROI - Return On Investment  Operating Cash Flow Per Share  \
# 0                      4.4530                         1.9957
# 1                     21.8765                         0.2501
# 2                      9.6494                        -7.6079
# 3                      5.1018                         1.7438
# 4                      8.1844                         1.9725
#
#    Free Cash Flow Per Share
# 0                   -0.1333
# 1                    0.3132
# 2                   -7.3231
# 3                   -0.8999
# 4                    2.4174
#
# [5 rows x 21 columns]

# %%
reduced_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7805 entries, 0 to 7804
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Rating Agency                  7805 non-null   object
#  1   Corporation                    7805 non-null   object
#  2   Rating                         7805 non-null   object
#  3   Binary Rating                  7805 non-null   int64
#  4   Sector                         7805 non-null   object
#  5   Current Ratio                  7805 non-null   float64
#  6   Long-term Debt / Capital       7805 non-null   float64
#  7   Debt/Equity Ratio              7805 non-null   float64
#  8   Gross Margin                   7805 non-null   float64
#  9   Operating Margin               7805 non-null   float64
#  10  EBIT Margin                    7805 non-null   float64
#  11  EBITDA Margin                  7805 non-null   float64
#  12  Pre-Tax Profit Margin          7805 non-null   float64
#  13  Net Profit Margin              7805 non-null   float64
#  14  Asset Turnover                 7805 non-null   float64
#  15  ROE - Return On Equity         7805 non-null   float64
#  16  Return On Tangible Equity      7805 non-null   float64
#  17  ROA - Return On Assets         7805 non-null   float64
#  18  ROI - Return On Investment     7805 non-null   float64
#  19  Operating Cash Flow Per Share  7805 non-null   float64
#  20  Free Cash Flow Per Share       7805 non-null   float64
# dtypes: float64(16), int64(1), object(4)
# memory usage: 1.3+ MB

# %%
reduced_df.shape
# Out:
# (7805, 21)

# %% [markdown]
# ### Step 2: Scale the `df_stocks` DataFrame and create a new DataFrame that contains the scaled data.

# %%
# Scale price data, return, and variance values
data_scaled = StandardScaler().fit_transform(
    reduced_df[["Current Ratio", "Long-term Debt / Capital", "Debt/Equity Ratio", "Gross Margin", "Operating Margin", "EBIT Margin", "EBITDA Margin", \
        "Pre-Tax Profit Margin", "Net Profit Margin", "Asset Turnover", "ROE - Return On Equity", "Return On Tangible Equity", "ROA - Return On Assets", \
        "ROI - Return On Investment", "Operating Cash Flow Per Share", "Free Cash Flow Per Share"]]
)

# %%
# Create a DataFrame with the scaled data
df_scaled = pd.DataFrame(
    data_scaled,
    columns=["Current Ratio", "Long-term Debt / Capital", "Debt/Equity Ratio", "Gross Margin", "Operating Margin", "EBIT Margin", "EBITDA Margin", \
        "Pre-Tax Profit Margin", "Net Profit Margin", "Asset Turnover", "ROE - Return On Equity", "Return On Tangible Equity", "ROA - Return On Assets", \
        "ROI - Return On Investment", "Operating Cash Flow Per Share", "Free Cash Flow Per Share"]
)

# Copy the tickers names from the original data
#df_scaled["Corporation"] = df['Corporation']

# shift column 'Name' to first position 
first_column = df.pop('Corporation') 
  
# insert column using insert(position,column_name, 
# first_column) function 
df_scaled.insert(0, 'Corporation', first_column) 

# Set the Ticker column as index
# df_scaled = df_scaled.set_index("Corporation")

# Display sample data
df_scaled.head()
# Out:
#                       Corporation  Current Ratio  Long-term Debt / Capital  \
# 0       American States Water Co.      -0.403644                  0.000873
# 1  Automatic Data Processing Inc.      -0.423316                 -0.169496
# 2                      Avnet Inc.       0.000670                 -0.061013
# 3    California Water Service Co.      -0.567524                  0.006845
# 4            Cardinal Health Inc.      -0.329536                 -0.071664
#
#    Debt/Equity Ratio  Gross Margin  Operating Margin  EBIT Margin  \
# 0           0.020530      1.482239          0.312253     0.310067
# 1          -0.004936      0.051726          0.325949     0.323755
# 2           0.007202     -1.286119         -0.322542    -0.324358
# 3           0.022399      0.929875          0.271849     0.269686
# 4           0.006567     -1.625720         -0.400697    -0.402467
#
#    EBITDA Margin  Pre-Tax Profit Margin  Net Profit Margin  Asset Turnover  \
# 0       0.365559               0.177621           0.096734       -0.764973
# 1       0.158597               0.438188           0.314851       -0.743282
# 2      -0.674261              -0.201199          -0.160213        2.315788
# 3       0.322665               0.231604           0.125926       -0.797580
# 4      -0.758313              -0.266630          -0.222157        5.857507
#
#    ROE - Return On Equity  Return On Tangible Equity  ROA - Return On Assets  \
# 0               -0.033733                  -0.028709               -0.209897
# 1                0.026390                   0.055768               -0.008809
# 2               -0.010031                  -0.010120                0.075563
# 3               -0.027363                  -0.025459               -0.207752
# 4               -0.020925                  -0.004459               -0.177620
#
#    ROI - Return On Investment  Operating Cash Flow Per Share  \
# 0                   -0.107590                       0.250559
# 1                    0.607060                      -0.037958
# 2                    0.105548                      -1.336750
# 3                   -0.080978                       0.208925
# 4                    0.045459                       0.246725
#
#    Free Cash Flow Per Share
# 0                 -0.034852
# 1                  0.026707
# 2                 -1.026112
# 3                 -0.140544
# 4                  0.316813

# %%
# Encode the "EnergyType" column to variables to categorize oil versus non-oil firms. 
dummies = pd.get_dummies(df, columns=['Rating', 'Sector'])
dummies.head()
# Out:
#                         Rating Agency Rating Date      CIK  Binary Rating  \
# 0  Standard & Poor's Ratings Services  2010-07-30  1056903              1
# 1  Standard & Poor's Ratings Services  2010-09-16     8670              1
# 2  Standard & Poor's Ratings Services  2010-11-23     8858              1
# 3  Standard & Poor's Ratings Services  2010-06-29  1035201              1
# 4  Standard & Poor's Ratings Services  2010-07-14   721371              1
#
#    SIC Code Ticker  Current Ratio  Long-term Debt / Capital  \
# 0    4941.0    AWR         1.1507                    0.4551
# 1    7374.0    ADP         1.1129                    0.0072
# 2    5065.0    AVT         1.9276                    0.2924
# 3    4941.0    CWT         0.8358                    0.4708
# 4    5122.0    CAH         1.2931                    0.2644
#
#    Debt/Equity Ratio  Gross Margin  ...  Sector_Durbl  Sector_Enrgy  \
# 0             0.8847       77.6230  ...         False         False
# 1             0.0073       43.6619  ...         False         False
# 2             0.4255       11.9008  ...         False         False
# 3             0.9491       64.5096  ...         False         False
# 4             0.4036        3.8385  ...         False         False
#
#    Sector_Hlth  Sector_Manuf  Sector_Money  Sector_NoDur  Sector_Other  \
# 0        False         False         False         False         False
# 1        False         False         False         False         False
# 2        False         False         False         False         False
# 3        False         False         False         False         False
# 4        False         False         False         False         False
#
#    Sector_Shops  Sector_Telcm  Sector_Utils
# 0         False         False          True
# 1         False         False         False
# 2          True         False         False
# 3         False         False          True
# 4          True         False         False
#
# [5 rows x 57 columns]

# %%
# Concatenate the "EnergyType" variables with the scaled data DataFrame.
df_scaled = pd.concat([df_scaled, dummies], axis=1)

# Display the sample data
df_scaled.head()
# Out:
#                       Corporation  Current Ratio  Long-term Debt / Capital  \
# 0       American States Water Co.      -0.403644                  0.000873
# 1  Automatic Data Processing Inc.      -0.423316                 -0.169496
# 2                      Avnet Inc.       0.000670                 -0.061013
# 3    California Water Service Co.      -0.567524                  0.006845
# 4            Cardinal Health Inc.      -0.329536                 -0.071664
#
#    Debt/Equity Ratio  Gross Margin  Operating Margin  EBIT Margin  \
# 0           0.020530      1.482239          0.312253     0.310067
# 1          -0.004936      0.051726          0.325949     0.323755
# 2           0.007202     -1.286119         -0.322542    -0.324358
# 3           0.022399      0.929875          0.271849     0.269686
# 4           0.006567     -1.625720         -0.400697    -0.402467
#
#    EBITDA Margin  Pre-Tax Profit Margin  Net Profit Margin  ...  Sector_Durbl  \
# 0       0.365559               0.177621           0.096734  ...         False
# 1       0.158597               0.438188           0.314851  ...         False
# 2      -0.674261              -0.201199          -0.160213  ...         False
# 3       0.322665               0.231604           0.125926  ...         False
# 4      -0.758313              -0.266630          -0.222157  ...         False
#
#    Sector_Enrgy  Sector_Hlth  Sector_Manuf  Sector_Money  Sector_NoDur  \
# 0         False        False         False         False         False
# 1         False        False         False         False         False
# 2         False        False         False         False         False
# 3         False        False         False         False         False
# 4         False        False         False         False         False
#
#    Sector_Other Sector_Shops Sector_Telcm  Sector_Utils
# 0         False        False        False          True
# 1         False        False        False         False
# 2         False         True        False         False
# 3         False        False        False          True
# 4         False         True        False         False
#
# [5 rows x 74 columns]

# %%
# Create a a list to store inertia values
inertia = []

# Create a a list to store the values of k
k = list(range(1, 11))

# Create copy of df without corporation field
df_copy = df_scaled
df_copy = df_copy.drop(columns=['Corporation', 'Ticker', 'Rating Agency', 'Rating Date'])
df_copy.head()
# Out:
#    Current Ratio  Long-term Debt / Capital  Debt/Equity Ratio  Gross Margin  \
# 0      -0.403644                  0.000873           0.020530      1.482239
# 1      -0.423316                 -0.169496          -0.004936      0.051726
# 2       0.000670                 -0.061013           0.007202     -1.286119
# 3      -0.567524                  0.006845           0.022399      0.929875
# 4      -0.329536                 -0.071664           0.006567     -1.625720
#
#    Operating Margin  EBIT Margin  EBITDA Margin  Pre-Tax Profit Margin  \
# 0          0.312253     0.310067       0.365559               0.177621
# 1          0.325949     0.323755       0.158597               0.438188
# 2         -0.322542    -0.324358      -0.674261              -0.201199
# 3          0.271849     0.269686       0.322665               0.231604
# 4         -0.400697    -0.402467      -0.758313              -0.266630
#
#    Net Profit Margin  Asset Turnover  ...  Sector_Durbl  Sector_Enrgy  \
# 0           0.096734       -0.764973  ...         False         False
# 1           0.314851       -0.743282  ...         False         False
# 2          -0.160213        2.315788  ...         False         False
# 3           0.125926       -0.797580  ...         False         False
# 4          -0.222157        5.857507  ...         False         False
#
#    Sector_Hlth  Sector_Manuf  Sector_Money  Sector_NoDur  Sector_Other  \
# 0        False         False         False         False         False
# 1        False         False         False         False         False
# 2        False         False         False         False         False
# 3        False         False         False         False         False
# 4        False         False         False         False         False
#
#    Sector_Shops  Sector_Telcm  Sector_Utils
# 0         False         False          True
# 1         False         False         False
# 2          True         False         False
# 3         False         False          True
# 4          True         False         False
#
# [5 rows x 70 columns]

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7805 entries, 0 to 7804
# Data columns (total 70 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Current Ratio                  7805 non-null   float64
#  1   Long-term Debt / Capital       7805 non-null   float64
#  2   Debt/Equity Ratio              7805 non-null   float64
#  3   Gross Margin                   7805 non-null   float64
#  4   Operating Margin               7805 non-null   float64
#  5   EBIT Margin                    7805 non-null   float64
#  6   EBITDA Margin                  7805 non-null   float64
#  7   Pre-Tax Profit Margin          7805 non-null   float64
#  8   Net Profit Margin              7805 non-null   float64
#  9   Asset Turnover                 7805 non-null   float64
#  10  ROE - Return On Equity         7805 non-null   float64
#  11  Return On Tangible Equity      7805 non-null   float64
#  12  ROA - Return On Assets         7805 non-null   float64
#  13  ROI - Return On Investment     7805 non-null   float64
#  14  Operating Cash Flow Per Share  7805 non-null   float64
#  15  Free Cash Flow Per Share       7805 non-null   float64
#  16  CIK                            7805 non-null   int64
#  17  Binary Rating                  7805 non-null   int64
#  18  SIC Code                       7805 non-null   float64
#  19  Current Ratio                  7805 non-null   float64
#  20  Long-term Debt / Capital       7805 non-null   float64
#  21  Debt/Equity Ratio              7805 non-null   float64
#  22  Gross Margin                   7805 non-null   float64
#  23  Operating Margin               7805 non-null   float64
#  24  EBIT Margin                    7805 non-null   float64
#  25  EBITDA Margin                  7805 non-null   float64
#  26  Pre-Tax Profit Margin          7805 non-null   float64
#  27  Net Profit Margin              7805 non-null   float64
#  28  Asset Turnover                 7805 non-null   float64
#  29  ROE - Return On Equity         7805 non-null   float64
#  30  Return On Tangible Equity      7805 non-null   float64
#  31  ROA - Return On Assets         7805 non-null   float64
#  32  ROI - Return On Investment     7805 non-null   float64
#  33  Operating Cash Flow Per Share  7805 non-null   float64
#  34  Free Cash Flow Per Share       7805 non-null   float64
#  35  Rating_A                       7805 non-null   bool
#  36  Rating_A+                      7805 non-null   bool
#  37  Rating_A-                      7805 non-null   bool
#  38  Rating_AA                      7805 non-null   bool
#  39  Rating_AA+                     7805 non-null   bool
#  40  Rating_AA-                     7805 non-null   bool
#  41  Rating_AAA                     7805 non-null   bool
#  42  Rating_B                       7805 non-null   bool
#  43  Rating_B+                      7805 non-null   bool
#  44  Rating_B-                      7805 non-null   bool
#  45  Rating_BB                      7805 non-null   bool
#  46  Rating_BB+                     7805 non-null   bool
#  47  Rating_BB-                     7805 non-null   bool
#  48  Rating_BBB                     7805 non-null   bool
#  49  Rating_BBB+                    7805 non-null   bool
#  50  Rating_BBB-                    7805 non-null   bool
#  51  Rating_C                       7805 non-null   bool
#  52  Rating_CC                      7805 non-null   bool
#  53  Rating_CC+                     7805 non-null   bool
#  54  Rating_CCC                     7805 non-null   bool
#  55  Rating_CCC+                    7805 non-null   bool
#  56  Rating_CCC-                    7805 non-null   bool
#  57  Rating_D                       7805 non-null   bool
#  58  Sector_BusEq                   7805 non-null   bool
#  59  Sector_Chems                   7805 non-null   bool
#  60  Sector_Durbl                   7805 non-null   bool
#  61  Sector_Enrgy                   7805 non-null   bool
#  62  Sector_Hlth                    7805 non-null   bool
#  63  Sector_Manuf                   7805 non-null   bool
#  64  Sector_Money                   7805 non-null   bool
#  65  Sector_NoDur                   7805 non-null   bool
#  66  Sector_Other                   7805 non-null   bool
#  67  Sector_Shops                   7805 non-null   bool
#  68  Sector_Telcm                   7805 non-null   bool
#  69  Sector_Utils                   7805 non-null   bool
# dtypes: bool(35), float64(33), int64(2)
# memory usage: 2.3 MB

# %%
# Create a for-loop where each value of k is evaluated using the K-means algorithm
for i in k:
    k_model = KMeans(n_clusters=i, random_state=2)
    k_model.fit(df_copy)
    inertia.append(k_model.inertia_)

# Create a Dictionary that holds the list values for k and inertia
elbow_data = {"k": k, "inertia": inertia}

# Create a DataFrame using the elbow_data Dictionary
df_elbow = pd.DataFrame(elbow_data)

# Review the DataFrame
df_elbow.head()
# Out:
#    k       inertia
# 0  1  2.064657e+15
# 1  2  3.582538e+14
# 2  3  1.117985e+14
# 3  4  5.862009e+13
# 4  5  4.133709e+13

# %%
# Plot Elbow Curve
df_elbow.hvplot.line(
    x="k", 
    y="inertia", 
    title="Elbow Curve", 
    xticks=k
)
# Out:
# :Curve   [k]   (inertia)

# %%
# Initialize the K-Means model with n_clusters=3
model = KMeans(n_clusters=3)

# %%
# Fit the model for the df_stocks_scaled DataFrame
model.fit(df_copy)
# Out:
# KMeans(n_clusters=3)

# %%
# Predict the model segments (clusters)
clusters = model.predict(df_copy)

# View the stock segments
print(clusters)
# Out:
# [2 1 1 ... 2 2 2]

# %%
unique = np.unique(clusters)
unique
# Out:
# array([0, 1, 2])

# %%
# Create a new column in the DataFrame with the predicted clusters
df_scaled["Clusters"] = clusters

# Review the DataFrame
df_scaled.head()
# Out:
#                       Corporation  Current Ratio  Long-term Debt / Capital  \
# 0       American States Water Co.      -0.403644                  0.000873
# 1  Automatic Data Processing Inc.      -0.423316                 -0.169496
# 2                      Avnet Inc.       0.000670                 -0.061013
# 3    California Water Service Co.      -0.567524                  0.006845
# 4            Cardinal Health Inc.      -0.329536                 -0.071664
#
#    Debt/Equity Ratio  Gross Margin  Operating Margin  EBIT Margin  \
# 0           0.020530      1.482239          0.312253     0.310067
# 1          -0.004936      0.051726          0.325949     0.323755
# 2           0.007202     -1.286119         -0.322542    -0.324358
# 3           0.022399      0.929875          0.271849     0.269686
# 4           0.006567     -1.625720         -0.400697    -0.402467
#
#    EBITDA Margin  Pre-Tax Profit Margin  Net Profit Margin  ...  Sector_Enrgy  \
# 0       0.365559               0.177621           0.096734  ...         False
# 1       0.158597               0.438188           0.314851  ...         False
# 2      -0.674261              -0.201199          -0.160213  ...         False
# 3       0.322665               0.231604           0.125926  ...         False
# 4      -0.758313              -0.266630          -0.222157  ...         False
#
#    Sector_Hlth  Sector_Manuf  Sector_Money  Sector_NoDur  Sector_Other  \
# 0        False         False         False         False         False
# 1        False         False         False         False         False
# 2        False         False         False         False         False
# 3        False         False         False         False         False
# 4        False         False         False         False         False
#
#    Sector_Shops Sector_Telcm Sector_Utils  Clusters
# 0         False        False         True         2
# 1         False        False        False         1
# 2          True        False        False         1
# 3         False        False         True         2
# 4          True        False        False         2
#
# [5 rows x 75 columns]

# %%
# Create the PCA model instance where n_components=2
pca = PCA(n_components=2)

# %%
# Fit the df_stocks_scaled data to the PCA
pca_data = pca.fit_transform(df_copy)

# Review the first five rose of the PCA data
# using bracket notation ([0:5])
pca_data[:5]
# Out:
# array([[ 319741.64171363,     801.32823232],
#        [-728490.65730188,    3519.62047625],
#        [-728303.28509063,    1210.2331348 ],
#        [ 298039.64247256,     807.23394553],
#        [ -15790.2966805 ,    1073.49894357]])

# %%
# Calculate the explained variance
pca.explained_variance_ratio_
# Out:
# array([9.99985814e-01, 1.31574379e-05])

# %%
# Creating a DataFrame with the PCA data
df_pca = pd.DataFrame(pca_data, columns=["PC1", "PC2"])

# Copy the  names from the original data
# df_pca.insert(0, 'Corporation', first_column)

# Review the DataFrame
df_pca.head()
# Out:
#              PC1          PC2
# 0  319741.641714   801.328232
# 1 -728490.657302  3519.620476
# 2 -728303.285091  1210.233135
# 3  298039.642473   807.233946
# 4  -15790.296680  1073.498944

# %%
# Initialize the K-Means model with n_clusters=3
model = KMeans(n_clusters=3)

# Fit the model for the df_stocks_pca DataFrame
model.fit(df_pca)

# Predict the model segments (clusters)
clusters2 = model.predict(df_pca)

# Print the stock segments
print(clusters2)
# Out:
# [0 1 1 ... 0 0 0]

# %%
# Create a copy of the df_stocks_pca DataFrame and name it as df_stocks_pca_predictions
df_pca_predictions = df_pca.copy()

# Create a new column in the DataFrame with the predicted clusters
df_pca_predictions["Cluster"] = clusters2

# Review the DataFrame
df_pca_predictions.head()
# Out:
#              PC1          PC2  Cluster
# 0  319741.641714   801.328232        0
# 1 -728490.657302  3519.620476        1
# 2 -728303.285091  1210.233135        1
# 3  298039.642473   807.233946        0
# 4  -15790.296680  1073.498944        0

# %%
# Create a list with the number of k-values to try
# Use a range from 1 to 11
k = list(range(1, 11))

# %%
# Create an empy list to store the inertia values
inertia = []

# %%
# Create a for loop to compute the inertia with each possible value of k
# Inside the loop:
# 1. Create a KMeans model using the loop counter for the n_clusters
# 2. Fit the model to the data using `df_stocks_pca`
# 3. Append the model.inertia_ to the inertia list
for i in k:
    model = KMeans(n_clusters=i, random_state=0)
    model.fit(df_pca_predictions)
    inertia.append(model.inertia_)

# %%
# Create a dictionary with the data to plot the Elbow curve
elbow_data_pca = {
    "k": k,
    "inertia": inertia
}

# Create a DataFrame with the data to plot the Elbow curve
df_elbow_pca = pd.DataFrame(elbow_data_pca)

# %%
# Plot a line chart with all the inertia values computed with 
# the different values of k to visually identify the optimal value for k.
elbow_plot_pca = df_elbow_pca.hvplot.line(x="k", y="inertia", title="Elbow Curve Using PCA Data", xticks=k)
elbow_plot_pca
# Out:
# :Curve   [k]   (inertia)

# %%
df_copy.columns
# Out:
# Index(['Current Ratio', 'Long-term Debt / Capital', 'Debt/Equity Ratio',
#        'Gross Margin', 'Operating Margin', 'EBIT Margin', 'EBITDA Margin',
#        'Pre-Tax Profit Margin', 'Net Profit Margin', 'Asset Turnover',
#        'ROE - Return On Equity', 'Return On Tangible Equity',
#        'ROA - Return On Assets', 'ROI - Return On Investment',
#        'Operating Cash Flow Per Share', 'Free Cash Flow Per Share', 'CIK',
#        'Binary Rating', 'SIC Code', 'Current Ratio',
#        'Long-term Debt / Capital', 'Debt/Equity Ratio', 'Gross Margin',
#        'Operating Margin', 'EBIT Margin', 'EBITDA Margin',
#        'Pre-Tax Profit Margin', 'Net Profit Margin', 'Asset Turnover',
#        'ROE - Return On Equity', 'Return On Tangible Equity',
#        'ROA - Return On Assets', 'ROI - Return On Investment',
#        'Operating Cash Flow Per Share', 'Free Cash Flow Per Share', 'Rating_A',
#        'Rating_A+', 'Rating_A-', 'Rating_AA', 'Rating_AA+', 'Rating_AA-',
#        'Rating_AAA', 'Rating_B', 'Rating_B+', 'Rating_B-', 'Rating_BB',
#        'Rating_BB+', 'Rating_BB-', 'Rating_BBB', 'Rating_BBB+', 'Rating_BBB-',
#        'Rating_C', 'Rating_CC', 'Rating_CC+', 'Rating_CCC', 'Rating_CCC+',
#        'Rating_CCC-', 'Rating_D', 'Sector_BusEq', 'Sector_Chems',
#        'Sector_Durbl', 'Sector_Enrgy', 'Sector_Hlth', 'Sector_Manuf',
#        'Sector_Money', 'Sector_NoDur', 'Sector_Other', 'Sector_Shops',
#        'Sector_Telcm', 'Sector_Utils'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Rating Agency', 'Rating', 'Rating Date', 'CIK', 'Binary Rating',
#        'SIC Code', 'Sector', 'Ticker', 'Current Ratio',
#        'Long-term Debt / Capital', 'Debt/Equity Ratio', 'Gross Margin',
#        'Operating Margin', 'EBIT Margin', 'EBITDA Margin',
#        'Pre-Tax Profit Margin', 'Net Profit Margin', 'Asset Turnover',
#        'ROE - Return On Equity', 'Return On Tangible Equity',
#        'ROA - Return On Assets', 'ROI - Return On Investment',
#        'Operating Cash Flow Per Share', 'Free Cash Flow Per Share'],
#       dtype='object')

# %%
# shift column 'Name' to first position 
#first_column = df.pop('Corporation') 
  
# insert column using insert(position,column_name, 
# first_column) function 
df_copy.insert(0, 'Corporation', first_column) 
df_copy.head()
# Out:
#                       Corporation  Current Ratio  Long-term Debt / Capital  \
# 0       American States Water Co.      -0.403644                  0.000873
# 1  Automatic Data Processing Inc.      -0.423316                 -0.169496
# 2                      Avnet Inc.       0.000670                 -0.061013
# 3    California Water Service Co.      -0.567524                  0.006845
# 4            Cardinal Health Inc.      -0.329536                 -0.071664
#
#    Debt/Equity Ratio  Gross Margin  Operating Margin  EBIT Margin  \
# 0           0.020530      1.482239          0.312253     0.310067
# 1          -0.004936      0.051726          0.325949     0.323755
# 2           0.007202     -1.286119         -0.322542    -0.324358
# 3           0.022399      0.929875          0.271849     0.269686
# 4           0.006567     -1.625720         -0.400697    -0.402467
#
#    EBITDA Margin  Pre-Tax Profit Margin  Net Profit Margin  ...  Sector_Durbl  \
# 0       0.365559               0.177621           0.096734  ...         False
# 1       0.158597               0.438188           0.314851  ...         False
# 2      -0.674261              -0.201199          -0.160213  ...         False
# 3       0.322665               0.231604           0.125926  ...         False
# 4      -0.758313              -0.266630          -0.222157  ...         False
#
#    Sector_Enrgy  Sector_Hlth  Sector_Manuf  Sector_Money  Sector_NoDur  \
# 0         False        False         False         False         False
# 1         False        False         False         False         False
# 2         False        False         False         False         False
# 3         False        False         False         False         False
# 4         False        False         False         False         False
#
#    Sector_Other  Sector_Shops  Sector_Telcm  Sector_Utils
# 0         False         False         False          True
# 1         False         False         False         False
# 2         False          True         False         False
# 3         False         False         False          True
# 4         False          True         False         False
#
# [5 rows x 71 columns]

# %%
agency = df.pop('Rating Agency')

df_copy.insert(1, 'Rating Agency', agency)
df_copy.head()
# Out:
#                       Corporation                       Rating Agency  \
# 0       American States Water Co.  Standard & Poor's Ratings Services
# 1  Automatic Data Processing Inc.  Standard & Poor's Ratings Services
# 2                      Avnet Inc.  Standard & Poor's Ratings Services
# 3    California Water Service Co.  Standard & Poor's Ratings Services
# 4            Cardinal Health Inc.  Standard & Poor's Ratings Services
#
#    Current Ratio  Long-term Debt / Capital  Debt/Equity Ratio  Gross Margin  \
# 0      -0.403644                  0.000873           0.020530      1.482239
# 1      -0.423316                 -0.169496          -0.004936      0.051726
# 2       0.000670                 -0.061013           0.007202     -1.286119
# 3      -0.567524                  0.006845           0.022399      0.929875
# 4      -0.329536                 -0.071664           0.006567     -1.625720
#
#    Operating Margin  EBIT Margin  EBITDA Margin  Pre-Tax Profit Margin  ...  \
# 0          0.312253     0.310067       0.365559               0.177621  ...
# 1          0.325949     0.323755       0.158597               0.438188  ...
# 2         -0.322542    -0.324358      -0.674261              -0.201199  ...
# 3          0.271849     0.269686       0.322665               0.231604  ...
# 4         -0.400697    -0.402467      -0.758313              -0.266630  ...
#
#    Sector_Durbl  Sector_Enrgy  Sector_Hlth  Sector_Manuf  Sector_Money  \
# 0         False         False        False         False         False
# 1         False         False        False         False         False
# 2         False         False        False         False         False
# 3         False         False        False         False         False
# 4         False         False        False         False         False
#
#    Sector_NoDur  Sector_Other  Sector_Shops  Sector_Telcm  Sector_Utils
# 0         False         False         False         False          True
# 1         False         False         False         False         False
# 2         False         False          True         False         False
# 3         False         False         False         False          True
# 4         False         False          True         False         False
#
# [5 rows x 72 columns]

# %%
rating = df.pop('Rating')

df_copy.insert(2, 'Rating', rating)
df_copy.head()
# Out:
#                       Corporation                       Rating Agency Rating  \
# 0       American States Water Co.  Standard & Poor's Ratings Services     A-
# 1  Automatic Data Processing Inc.  Standard & Poor's Ratings Services    AAA
# 2                      Avnet Inc.  Standard & Poor's Ratings Services   BBB-
# 3    California Water Service Co.  Standard & Poor's Ratings Services    AA-
# 4            Cardinal Health Inc.  Standard & Poor's Ratings Services      A
#
#    Current Ratio  Long-term Debt / Capital  Debt/Equity Ratio  Gross Margin  \
# 0      -0.403644                  0.000873           0.020530      1.482239
# 1      -0.423316                 -0.169496          -0.004936      0.051726
# 2       0.000670                 -0.061013           0.007202     -1.286119
# 3      -0.567524                  0.006845           0.022399      0.929875
# 4      -0.329536                 -0.071664           0.006567     -1.625720
#
#    Operating Margin  EBIT Margin  EBITDA Margin  ...  Sector_Durbl  \
# 0          0.312253     0.310067       0.365559  ...         False
# 1          0.325949     0.323755       0.158597  ...         False
# 2         -0.322542    -0.324358      -0.674261  ...         False
# 3          0.271849     0.269686       0.322665  ...         False
# 4         -0.400697    -0.402467      -0.758313  ...         False
#
#    Sector_Enrgy  Sector_Hlth  Sector_Manuf  Sector_Money  Sector_NoDur  \
# 0         False        False         False         False         False
# 1         False        False         False         False         False
# 2         False        False         False         False         False
# 3         False        False         False         False         False
# 4         False        False         False         False         False
#
#    Sector_Other  Sector_Shops  Sector_Telcm  Sector_Utils
# 0         False         False         False          True
# 1         False         False         False         False
# 2         False          True         False         False
# 3         False         False         False          True
# 4         False          True         False         False
#
# [5 rows x 73 columns]

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7805 entries, 0 to 7804
# Data columns (total 73 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Corporation                    7805 non-null   object
#  1   Rating Agency                  7805 non-null   object
#  2   Rating                         7805 non-null   object
#  3   Current Ratio                  7805 non-null   float64
#  4   Long-term Debt / Capital       7805 non-null   float64
#  5   Debt/Equity Ratio              7805 non-null   float64
#  6   Gross Margin                   7805 non-null   float64
#  7   Operating Margin               7805 non-null   float64
#  8   EBIT Margin                    7805 non-null   float64
#  9   EBITDA Margin                  7805 non-null   float64
#  10  Pre-Tax Profit Margin          7805 non-null   float64
#  11  Net Profit Margin              7805 non-null   float64
#  12  Asset Turnover                 7805 non-null   float64
#  13  ROE - Return On Equity         7805 non-null   float64
#  14  Return On Tangible Equity      7805 non-null   float64
#  15  ROA - Return On Assets         7805 non-null   float64
#  16  ROI - Return On Investment     7805 non-null   float64
#  17  Operating Cash Flow Per Share  7805 non-null   float64
#  18  Free Cash Flow Per Share       7805 non-null   float64
#  19  CIK                            7805 non-null   int64
#  20  Binary Rating                  7805 non-null   int64
#  21  SIC Code                       7805 non-null   float64
#  22  Current Ratio                  7805 non-null   float64
#  23  Long-term Debt / Capital       7805 non-null   float64
#  24  Debt/Equity Ratio              7805 non-null   float64
#  25  Gross Margin                   7805 non-null   float64
#  26  Operating Margin               7805 non-null   float64
#  27  EBIT Margin                    7805 non-null   float64
#  28  EBITDA Margin                  7805 non-null   float64
#  29  Pre-Tax Profit Margin          7805 non-null   float64
#  30  Net Profit Margin              7805 non-null   float64
#  31  Asset Turnover                 7805 non-null   float64
#  32  ROE - Return On Equity         7805 non-null   float64
#  33  Return On Tangible Equity      7805 non-null   float64
#  34  ROA - Return On Assets         7805 non-null   float64
#  35  ROI - Return On Investment     7805 non-null   float64
#  36  Operating Cash Flow Per Share  7805 non-null   float64
#  37  Free Cash Flow Per Share       7805 non-null   float64
#  38  Rating_A                       7805 non-null   bool
#  39  Rating_A+                      7805 non-null   bool
#  40  Rating_A-                      7805 non-null   bool
#  41  Rating_AA                      7805 non-null   bool
#  42  Rating_AA+                     7805 non-null   bool
#  43  Rating_AA-                     7805 non-null   bool
#  44  Rating_AAA                     7805 non-null   bool
#  45  Rating_B                       7805 non-null   bool
#  46  Rating_B+                      7805 non-null   bool
#  47  Rating_B-                      7805 non-null   bool
#  48  Rating_BB                      7805 non-null   bool
#  49  Rating_BB+                     7805 non-null   bool
#  50  Rating_BB-                     7805 non-null   bool
#  51  Rating_BBB                     7805 non-null   bool
#  52  Rating_BBB+                    7805 non-null   bool
#  53  Rating_BBB-                    7805 non-null   bool
#  54  Rating_C                       7805 non-null   bool
#  55  Rating_CC                      7805 non-null   bool
#  56  Rating_CC+                     7805 non-null   bool
#  57  Rating_CCC                     7805 non-null   bool
#  58  Rating_CCC+                    7805 non-null   bool
#  59  Rating_CCC-                    7805 non-null   bool
#  60  Rating_D                       7805 non-null   bool
#  61  Sector_BusEq                   7805 non-null   bool
#  62  Sector_Chems                   7805 non-null   bool
#  63  Sector_Durbl                   7805 non-null   bool
#  64  Sector_Enrgy                   7805 non-null   bool
#  65  Sector_Hlth                    7805 non-null   bool
#  66  Sector_Manuf                   7805 non-null   bool
#  67  Sector_Money                   7805 non-null   bool
#  68  Sector_NoDur                   7805 non-null   bool
#  69  Sector_Other                   7805 non-null   bool
#  70  Sector_Shops                   7805 non-null   bool
#  71  Sector_Telcm                   7805 non-null   bool
#  72  Sector_Utils                   7805 non-null   bool
# dtypes: bool(35), float64(33), int64(2), object(3)
# memory usage: 2.5+ MB

# %%
duplicate_columns = [
    'Current Ratio',
    'Long-term Debt / Capital',
    'Debt/Equity Ratio',
    'Gross Margin',
    'Operating Margin',
    'EBIT Margin',
    'EBITDA Margin',
    'Pre-Tax Profit Margin',
    'Net Profit Margin',
    'Asset Turnover',
    'ROE - Return On Equity',
    'Return On Tangible Equity',
    'ROA - Return On Assets',
    'ROI - Return On Investment',
    'Operating Cash Flow Per Share',
    'Free Cash Flow Per Share'
]

df_copy.drop(duplicate_columns, axis=1, inplace=True)

# %%
df_pca_predictions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7805 entries, 0 to 7804
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   PC1      7805 non-null   float64
#  1   PC2      7805 non-null   float64
#  2   Cluster  7805 non-null   int32
# dtypes: float64(2), int32(1)
# memory usage: 152.6 KB

# %%
df_2 = df_pca_predictions.copy()
df_2.insert(0, 'Corporation', first_column) 
br = df.pop('Binary Rating')
df_2.insert(2, 'Binary Rating', br)

df_2.head()
# Out:
#                       Corporation            PC1  Binary Rating          PC2  \
# 0       American States Water Co.  319741.641714              1   801.328232
# 1  Automatic Data Processing Inc. -728490.657302              1  3519.620476
# 2                      Avnet Inc. -728303.285091              1  1210.233135
# 3    California Water Service Co.  298039.642473              1   807.233946
# 4            Cardinal Health Inc.  -15790.296680              1  1073.498944
#
#    Cluster
# 0        0
# 1        1
# 2        1
# 3        0
# 4        0

# %%
# Connect to the database
conn = sqlite3.connect('../data/db.sqlite')


df_copy.to_sql('cluster', conn, index=False, if_exists='replace', dtype={'id': 'INTEGER PRIMARY KEY'})
df_2.to_sql('pca', conn, index=False, if_exists='replace', dtype={'id': 'INTEGER PRIMARY KEY'})

conn.close()
